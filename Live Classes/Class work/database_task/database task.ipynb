# %% [markdown]
# #### Home Task
#
# ##### Use the Attribute and Dress Sales dataset which are connected through Dress_ID column.
#
# **Everything should be done through Python**
#
# - Create a table for both the datasets.
# - Do a bulk load for these two tables for respective datasets (insert the data in one go).
# - Read these datasets in pandas as a dataframe.
# - Convert Attribute dataset into JSON format.
# - Store this json dataset into MongoDB. (again in one go)
# - In SQL try to perform left join operation with Attribute dataset(left side) and Sales dataset on column Dress_ID.
# - Write a sql query to find out how many unique dress that we have based on Dress_ID?
# - Try to find out how many dress is having Recommendation 0?
# - Try to find out total dress sale based on Dress_ID for each Dress_ID.
# - Try to find out third highest most selling Dress_ID.

# %%
# importing required libraries

import pandas as pd
import mysql.connector as conn
from mysql.connector import Error
from sqlalchemy import create_engine

# %%
# collecting data from excel file

df1 = pd.read_excel('datasets/Attribute Dataset.xlsx', index_col='Dress_ID')
df2 = pd.read_excel('datasets/Dress Sales.xlsx', index_col='Dress_ID')
pd.set_option('display.max_columns', None)

# %%
df1.head(2)
# Out:
#              Style Price  Rating Size  Season NeckLine SleeveLength waiseline  \
# Dress_ID
# 1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless    empire
# 1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal   natural
#
#               Material FabricType Decoration Pattern Type  Recommendation
# Dress_ID
# 1006032852         NaN    chiffon    ruffles       animal               1
# 1212192089  microfiber        NaN    ruffles       animal               0

# %%
df2.head(2)
# Out:
#             29/8/2013  31/8/2013  2013-02-09 00:00:00  2013-04-09 00:00:00  \
# Dress_ID
# 1006032852       2114       2274                 2491                 2660
# 1212192089        151        275                  570                  750
#
#             2013-06-09 00:00:00  2013-08-09 00:00:00  2013-10-09 00:00:00  \
# Dress_ID
# 1006032852                 2727                 2887                 2930
# 1212192089                  813                 1066                 1164
#
#            2013-12-09 00:00:00 14/9/2013 16/9/2013 18/9/2013 20/9/2013  \
# Dress_ID
# 1006032852                3119      3204      3277      3321      3386
# 1212192089                1558      1756      1878      1985      2106
#
#            22/9/2013  24/9/2013  26/9/2013  28/9/2013  30/9/2013  \
# Dress_ID
# 1006032852      3479       3554     3624.0       3706     3746.0
# 1212192089      2454       2710     2942.0       3258     3354.0
#
#             2013-02-10 00:00:00  2013-04-10 00:00:00  2013-06-10 00:00:00  \
# Dress_ID
# 1006032852               3795.0               3832.0                 3897
# 1212192089               3475.0               3654.0                 3911
#
#             2010-08-10 00:00:00  2013-10-10 00:00:00  2013-12-10 00:00:00
# Dress_ID
# 1006032852               3923.0               3985.0                 4048
# 1212192089               4024.0               4125.0                 4277

# %%
# Now to check the number of null values in df1

df1.isnull().sum()
# Out:
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# waiseline          87
# Material          128
# FabricType        266
# Decoration        236
# Pattern Type      109
# Recommendation      0
# dtype: int64

# %%
# Changing the null values to string 'None'

df1 = df1.fillna('None')
df1.head()
# Out:
#               Style    Price  Rating Size  Season NeckLine SleeveLength  \
# Dress_ID
# 1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 966005983     Brief  Average     4.6    L  Spring   o-neck         full
# 876339541      cute      Low     4.5    M  Summer   o-neck    butterfly
#
#            waiseline       Material FabricType  Decoration Pattern Type  \
# Dress_ID
# 1006032852    empire           None    chiffon     ruffles       animal
# 1212192089   natural     microfiber       None     ruffles       animal
# 1190380701   natural       polyster       None        None        print
# 966005983    natural           silk    chiffon  embroidary        print
# 876339541    natural  chiffonfabric    chiffon         bow          dot
#
#             Recommendation
# Dress_ID
# 1006032852               1
# 1212192089               0
# 1190380701               0
# 966005983                1
# 876339541                0

# %%
# again checking the null values

df1.isnull().sum()
# Out:
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# waiseline         0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# dtype: int64

# %%
# path to the directory

import os

os.getcwd()
# Out:
# 'F:\\Machine Learning\\INeuron_FSDS\\Live Classes\\database exercise'

# %%
# now storing this data as .csv file

df1.to_csv('F:\\Machine Learning\\INeuron_FSDS\\Live Classes\\database exercise\\datasets\\attributes.csv')

# %%
# Now same for df2

df2.isnull().sum()
# Out:
# 29/8/2013                0
# 31/8/2013                0
# 2013-02-09 00:00:00      0
# 2013-04-09 00:00:00      0
# 2013-06-09 00:00:00      0
# 2013-08-09 00:00:00      0
# 2013-10-09 00:00:00      0
# 2013-12-09 00:00:00      0
# 14/9/2013                0
# 16/9/2013                0
# 18/9/2013                0
# 20/9/2013                0
# 22/9/2013                0
# 24/9/2013                0
# 26/9/2013              237
# 28/9/2013                0
# 30/9/2013              273
# 2013-02-10 00:00:00    275
# 2013-04-10 00:00:00    274
# 2013-06-10 00:00:00      0
# 2010-08-10 00:00:00    271
# 2013-10-10 00:00:00    271
# 2013-12-10 00:00:00      0
# dtype: int64

# %%
# checking the column names types

for i in df2.columns:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>

# %%
# Changing the datetimes to str type in the column name

# creating function
def date_str(l):
    l1 = []
    for i in l:
        if type(i) != str:
            k = i.strftime('%d/%m/%Y')
            l1.append(k)
        else:
            l1.append(i)
    return l1

# calling the function
df3 = date_str(df2.columns.tolist())

# changing all the columns to str type
df2.columns = df3

# %%
# again checking the column names types

for i in df2.columns:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Now checking the null value types

df2[df2.isna()]
# Out:
#             29/8/2013  31/8/2013  09/02/2013  09/04/2013  09/06/2013  \
# Dress_ID
# 1006032852        NaN        NaN         NaN         NaN         NaN
# 1212192089        NaN        NaN         NaN         NaN         NaN
# 1190380701        NaN        NaN         NaN         NaN         NaN
# 966005983         NaN        NaN         NaN         NaN         NaN
# 876339541         NaN        NaN         NaN         NaN         NaN
# ...               ...        ...         ...         ...         ...
# 713391965         NaN        NaN         NaN         NaN         NaN
# 722565148         NaN        NaN         NaN         NaN         NaN
# 532874347         NaN        NaN         NaN         NaN         NaN
# 655464934         NaN        NaN         NaN         NaN         NaN
# 919930954         NaN        NaN         NaN         NaN         NaN
#
#             09/08/2013  09/10/2013 09/12/2013 14/9/2013 16/9/2013 18/9/2013  \
# Dress_ID
# 1006032852         NaN         NaN        NaN       NaN       NaN       NaN
# 1212192089         NaN         NaN        NaN       NaN       NaN       NaN
# 1190380701         NaN         NaN        NaN       NaN       NaN       NaN
# 966005983          NaN         NaN        NaN       NaN       NaN       NaN
# 876339541          NaN         NaN        NaN       NaN       NaN       NaN
# ...                ...         ...        ...       ...       ...       ...
# 713391965          NaN         NaN        NaN       NaN       NaN       NaN
# 722565148          NaN         NaN        NaN       NaN       NaN       NaN
# 532874347          NaN         NaN        NaN       NaN       NaN       NaN
# 655464934          NaN         NaN        NaN       NaN       NaN       NaN
# 919930954          NaN         NaN        NaN       NaN       NaN       NaN
#
#            20/9/2013 22/9/2013  24/9/2013  26/9/2013  28/9/2013  30/9/2013  \
# Dress_ID
# 1006032852       NaN       NaN        NaN        NaN        NaN        NaN
# 1212192089       NaN       NaN        NaN        NaN        NaN        NaN
# 1190380701       NaN       NaN        NaN        NaN        NaN        NaN
# 966005983        NaN       NaN        NaN        NaN        NaN        NaN
# 876339541        NaN       NaN        NaN        NaN        NaN        NaN
# ...              ...       ...        ...        ...        ...        ...
# 713391965        NaN       NaN        NaN        NaN        NaN        NaN
# 722565148        NaN       NaN        NaN        NaN        NaN        NaN
# 532874347        NaN       NaN        NaN        NaN        NaN        NaN
# 655464934        NaN       NaN        NaN        NaN        NaN        NaN
# 919930954        NaN       NaN        NaN        NaN        NaN        NaN
#
#             10/02/2013  10/04/2013  10/06/2013  10/08/2010  10/10/2013  \
# Dress_ID
# 1006032852         NaN         NaN         NaN         NaN         NaN
# 1212192089         NaN         NaN         NaN         NaN         NaN
# 1190380701         NaN         NaN         NaN         NaN         NaN
# 966005983          NaN         NaN         NaN         NaN         NaN
# 876339541          NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 713391965          NaN         NaN         NaN         NaN         NaN
# 722565148          NaN         NaN         NaN         NaN         NaN
# 532874347          NaN         NaN         NaN         NaN         NaN
# 655464934          NaN         NaN         NaN         NaN         NaN
# 919930954          NaN         NaN         NaN         NaN         NaN
#
#             10/12/2013
# Dress_ID
# 1006032852         NaN
# 1212192089         NaN
# 1190380701         NaN
# 966005983          NaN
# 876339541          NaN
# ...                ...
# 713391965          NaN
# 722565148          NaN
# 532874347          NaN
# 655464934          NaN
# 919930954          NaN
#
# [500 rows x 23 columns]

# %%
# Changing the null values to 0

df2 = df2.fillna(0)
df2.head()
# Out:
#             29/8/2013  31/8/2013  09/02/2013  09/04/2013  09/06/2013  \
# Dress_ID
# 1006032852       2114       2274        2491        2660        2727
# 1212192089        151        275         570         750         813
# 1190380701          6          7           7           7           8
# 966005983        1005       1128        1326        1455        1507
# 876339541         996       1175        1304        1396        1432
#
#             09/08/2013  09/10/2013 09/12/2013 14/9/2013 16/9/2013 18/9/2013  \
# Dress_ID
# 1006032852        2887        2930       3119      3204      3277      3321
# 1212192089        1066        1164       1558      1756      1878      1985
# 1190380701           8           9         10        10        10        10
# 966005983         1621        1637       1723      1746      1783      1796
# 876339541         1559        1570       1638      1655      1681      1743
#
#            20/9/2013 22/9/2013  24/9/2013  26/9/2013  28/9/2013  30/9/2013  \
# Dress_ID
# 1006032852      3386      3479       3554     3624.0       3706     3746.0
# 1212192089      2106      2454       2710     2942.0       3258     3354.0
# 1190380701        10        11         11       11.0         11       11.0
# 966005983       1812      1845       1878     1892.0       1914     1924.0
# 876339541       1824      1919       2032     2156.0       2252     2312.0
#
#             10/02/2013  10/04/2013  10/06/2013  10/08/2010  10/10/2013  \
# Dress_ID
# 1006032852      3795.0      3832.0        3897      3923.0      3985.0
# 1212192089      3475.0      3654.0        3911      4024.0      4125.0
# 1190380701        11.0        11.0          11        11.0        11.0
# 966005983       1929.0      1941.0        1952      1955.0      1959.0
# 876339541       2387.0      2459.0        2544      2614.0      2693.0
#
#             10/12/2013
# Dress_ID
# 1006032852        4048
# 1212192089        4277
# 1190380701          11
# 966005983         1963
# 876339541         2736

# %%
# now storing this data as .csv file

df2.to_csv('F:\\Machine Learning\\INeuron_FSDS\\Live Classes\\database exercise\\datasets\\sales.csv')

# %% [markdown]
# #### MySQL Part:

# %%
# Creating functions for MySQL

# Server connection
def create_server_connection(host_name, user_name, user_pwd):
    connection = None
    try:
        connection = conn.connect(host=host_name, user=user_name, passwd=user_pwd)

        print("Connection to MySQL is successful.")

    except Error as err:
        print(f"Error is: {err}")

    else:
        return connection
    

    
# Creating database
def create_database(connection, query):
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        print("Database created successfully")

    except Error as err:
        print(f"Error is: {err}")
        

        
# Connecting to the database
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = conn.connect(host=host_name, user=user_name, passwd=user_password, database=db_name)
        print("Connected to the Database Successfully")

    except Error as err:
        print(f"Error is: {err}")

    else:
        return connection
 


    
# Executing query
def execute_query(connection, query):
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        connection.commit()
        print("Query execution was successful")

    except Error as err:
        print(f"Error is: {err}")
        

        
        
# Showing query results
def read_query(connection, query):
    cursor = connection.cursor()
    result = None

    try:
        cursor.execute(query)
        result = cursor.fetchall()
        print("Query reading was successful")

    except Error as err:
        print(f"Error: {err}")

    else:
        return result

# %%
# Connection with MySQL

host = "localhost"
user = "root"
pw = "Password"

connection = create_server_connection(host, user, pw)
# Out:
# Connection to MySQL is successful.

# %%
# Creating the database

query = "CREATE DATABASE IF NOT EXISTS db_exercise"
create_database(connection, query)
# Out:
# Database created successfully

# %%
# Connecting with the database

db = "db_exercise"

db_connection = create_db_connection(host, user, pw, db)
# Out:
# Connected to the Database Successfully

# %%
# reading data from csv file

df = pd.read_csv('datasets/attributes.csv')
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# 1          Petal   natural     microfiber        None     ruffles
# 2           full   natural       polyster        None        None
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster        None        None
# 496         full    empire         cotton        None        None
# 497         full    empire         cotton        None        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496         None               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
# Checking the column names

df.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
# changing the column names with a gap between them

df.rename(columns = {'Pattern Type':'PatternType'}, inplace = True)
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration PatternType  \
# 0      sleevless    empire           None     chiffon     ruffles      animal
# 1          Petal   natural     microfiber        None     ruffles      animal
# 2           full   natural       polyster        None        None       print
# 3           full   natural           silk     chiffon  embroidary       print
# 4      butterfly   natural  chiffonfabric     chiffon         bow         dot
# ..           ...       ...            ...         ...         ...         ...
# 495         full   natural       polyster        None        None       solid
# 496         full    empire         cotton        None        None        None
# 497         full    empire         cotton        None        lace       solid
# 498    sleevless    empire           silk  broadcloth    applique       print
# 499        short    empire         cotton    Corduroy        lace       solid
#
#      Recommendation
# 0                 1
# 1                 0
# 2                 0
# 3                 1
# 4                 0
# ..              ...
# 495               1
# 496               0
# 497               1
# 498               1
# 499               0
#
# [500 rows x 14 columns]

# %%
engine = create_engine("mysql+pymysql://root:Password@localhost:3306/db_exercise")


try:
    df.to_sql(name='attributes', con=engine, index=False, if_exists='replace')
except Exception as e:
    print("Error is: ", e)
else:
    print("Query is Successful")
# Out:
# Query is Successful

# %%
# doing the same for the second table

df = pd.read_csv('datasets/sales.csv')
df
# Out:
#        Dress_ID  29/8/2013  31/8/2013  09/02/2013  09/04/2013  09/06/2013  \
# 0    1006032852       2114       2274        2491        2660        2727
# 1    1212192089        151        275         570         750         813
# 2    1190380701          6          7           7           7           8
# 3     966005983       1005       1128        1326        1455        1507
# 4     876339541        996       1175        1304        1396        1432
# ..          ...        ...        ...         ...         ...         ...
# 495   713391965          0          0           0         560         554
# 496   722565148          0          0           0         875         866
# 497   532874347          0          0           0         734         728
# 498   655464934          0          0           0         254         259
# 499   919930954          0          0           0         538         545
#
#      09/08/2013  09/10/2013 09/12/2013 14/9/2013 16/9/2013 18/9/2013  \
# 0          2887        2930       3119      3204      3277      3321
# 1          1066        1164       1558      1756      1878      1985
# 2             8           9         10        10        10        10
# 3          1621        1637       1723      1746      1783      1796
# 4          1559        1570       1638      1655      1681      1743
# ..          ...         ...        ...       ...       ...       ...
# 495         544         537        525       519       511       501
# 496         861         854        850       844       841       845
# 497         726         715        694       690       686       674
# 498         261         263        268       270       272       272
# 499         558         563        578       585       590       599
#
#     20/9/2013 22/9/2013  24/9/2013  26/9/2013  28/9/2013  30/9/2013  \
# 0        3386      3479       3554     3624.0       3706     3746.0
# 1        2106      2454       2710     2942.0       3258     3354.0
# 2          10        11         11       11.0         11       11.0
# 3        1812      1845       1878     1892.0       1914     1924.0
# 4        1824      1919       2032     2156.0       2252     2312.0
# ..        ...       ...        ...        ...        ...        ...
# 495       492       480        400      388.0        360      364.0
# 496       851       864        859      866.0        882      888.0
# 497       665       658        616      597.0        586      569.0
# 498       264       264        257      256.0        255      254.0
# 499       605       619        628      632.0        639      645.0
#
#      10/02/2013  10/04/2013  10/06/2013  10/08/2010  10/10/2013  10/12/2013
# 0        3795.0      3832.0        3897      3923.0      3985.0        4048
# 1        3475.0      3654.0        3911      4024.0      4125.0        4277
# 2          11.0        11.0          11        11.0        11.0          11
# 3        1929.0      1941.0        1952      1955.0      1959.0        1963
# 4        2387.0      2459.0        2544      2614.0      2693.0        2736
# ..          ...         ...         ...         ...         ...         ...
# 495       372.0       377.0         380       382.0       384.0         285
# 496       895.0       898.0         906       913.0       919.0         931
# 497       561.0       555.0         551       546.0       535.0         520
# 498       253.0       250.0         249       249.0       249.0         248
# 499       651.0       655.0         660       668.0       674.0         680
#
# [500 rows x 24 columns]

# %%
engine = create_engine("mysql+pymysql://root:Password@localhost:3306/db_exercise")


try:
    df.to_sql(name='sales', con=engine, index=False, if_exists='replace')
except Exception as e:
    print("Error is: ", e)
else:
    print("Query is Successful")
# Out:
# Query is Successful

# %%
# reading the datasets in pandas as dataframes

q1 = "SELECT * FROM attributes"
q2 = "SELECT * FROM sales"

df_attr = pd.read_sql(q1, con=engine, index_col='Dress_ID')
df_sale = pd.read_sql(q2, con=engine, index_col='Dress_ID')

# %%
df_attr
# Out:
#               Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# Dress_ID
# 1006032852     Sexy      Low     4.6     M  Summer     o-neck    sleevless
# 1212192089   Casual      Low     0.0     L  Summer     o-neck        Petal
# 1190380701  vintage     High     0.0     L  Automn     o-neck         full
# 966005983     Brief  Average     4.6     L  Spring     o-neck         full
# 876339541      cute      Low     4.5     M  Summer     o-neck    butterfly
# ...             ...      ...     ...   ...     ...        ...          ...
# 713391965    Casual      Low     4.7     M  Spring     o-neck         full
# 722565148      Sexy      Low     4.3  free  Summer     o-neck         full
# 532874347    Casual  Average     4.7     M  Summer     v-neck         full
# 655464934    Casual  Average     4.6     L  winter  boat-neck    sleevless
# 919930954    Casual      Low     4.4  free  Summer     v-neck        short
#
#            waiseline       Material  FabricType  Decoration PatternType  \
# Dress_ID
# 1006032852    empire           None     chiffon     ruffles      animal
# 1212192089   natural     microfiber        None     ruffles      animal
# 1190380701   natural       polyster        None        None       print
# 966005983    natural           silk     chiffon  embroidary       print
# 876339541    natural  chiffonfabric     chiffon         bow         dot
# ...              ...            ...         ...         ...         ...
# 713391965    natural       polyster        None        None       solid
# 722565148     empire         cotton        None        None        None
# 532874347     empire         cotton        None        lace       solid
# 655464934     empire           silk  broadcloth    applique       print
# 919930954     empire         cotton    Corduroy        lace       solid
#
#             Recommendation
# Dress_ID
# 1006032852               1
# 1212192089               0
# 1190380701               0
# 966005983                1
# 876339541                0
# ...                    ...
# 713391965                1
# 722565148                0
# 532874347                1
# 655464934                1
# 919930954                0
#
# [500 rows x 13 columns]

# %%
df_sale
# Out:
#             29/8/2013  31/8/2013  09/02/2013  09/04/2013  09/06/2013  \
# Dress_ID
# 1006032852       2114       2274        2491        2660        2727
# 1212192089        151        275         570         750         813
# 1190380701          6          7           7           7           8
# 966005983        1005       1128        1326        1455        1507
# 876339541         996       1175        1304        1396        1432
# ...               ...        ...         ...         ...         ...
# 713391965           0          0           0         560         554
# 722565148           0          0           0         875         866
# 532874347           0          0           0         734         728
# 655464934           0          0           0         254         259
# 919930954           0          0           0         538         545
#
#             09/08/2013  09/10/2013 09/12/2013 14/9/2013 16/9/2013 18/9/2013  \
# Dress_ID
# 1006032852        2887        2930       3119      3204      3277      3321
# 1212192089        1066        1164       1558      1756      1878      1985
# 1190380701           8           9         10        10        10        10
# 966005983         1621        1637       1723      1746      1783      1796
# 876339541         1559        1570       1638      1655      1681      1743
# ...                ...         ...        ...       ...       ...       ...
# 713391965          544         537        525       519       511       501
# 722565148          861         854        850       844       841       845
# 532874347          726         715        694       690       686       674
# 655464934          261         263        268       270       272       272
# 919930954          558         563        578       585       590       599
#
#            20/9/2013 22/9/2013  24/9/2013  26/9/2013  28/9/2013  30/9/2013  \
# Dress_ID
# 1006032852      3386      3479       3554     3624.0       3706     3746.0
# 1212192089      2106      2454       2710     2942.0       3258     3354.0
# 1190380701        10        11         11       11.0         11       11.0
# 966005983       1812      1845       1878     1892.0       1914     1924.0
# 876339541       1824      1919       2032     2156.0       2252     2312.0
# ...              ...       ...        ...        ...        ...        ...
# 713391965        492       480        400      388.0        360      364.0
# 722565148        851       864        859      866.0        882      888.0
# 532874347        665       658        616      597.0        586      569.0
# 655464934        264       264        257      256.0        255      254.0
# 919930954        605       619        628      632.0        639      645.0
#
#             10/02/2013  10/04/2013  10/06/2013  10/08/2010  10/10/2013  \
# Dress_ID
# 1006032852      3795.0      3832.0        3897      3923.0      3985.0
# 1212192089      3475.0      3654.0        3911      4024.0      4125.0
# 1190380701        11.0        11.0          11        11.0        11.0
# 966005983       1929.0      1941.0        1952      1955.0      1959.0
# 876339541       2387.0      2459.0        2544      2614.0      2693.0
# ...                ...         ...         ...         ...         ...
# 713391965        372.0       377.0         380       382.0       384.0
# 722565148        895.0       898.0         906       913.0       919.0
# 532874347        561.0       555.0         551       546.0       535.0
# 655464934        253.0       250.0         249       249.0       249.0
# 919930954        651.0       655.0         660       668.0       674.0
#
#             10/12/2013
# Dress_ID
# 1006032852        4048
# 1212192089        4277
# 1190380701          11
# 966005983         1963
# 876339541         2736
# ...                ...
# 713391965          285
# 722565148          931
# 532874347          520
# 655464934          248
# 919930954          680
#
# [500 rows x 23 columns]

# %% [markdown]
# #### Performing SQL Functions

# %%
# query for join operation
q = """
SELECT *
FROM
    attributes a
       LEFT JOIN
    sales s ON a.Dress_ID = s.Dress_ID;
"""

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)

# creating column names
cols = ['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine', 'SleeveLength', 'waiseline', 'Material',\
           'FabricType', 'Decoration', 'PatternType', 'Recommendation', 'Dress_ID', '29/8/2013', '31/8/2013', '09/02/2013',\
           '09/04/2013', '09/06/2013', '09/08/2013', '09/10/2013', '09/12/2013', '14/9/2013', '16/9/2013', '18/9/2013',\
           '20/9/2013', '22/9/2013', '24/9/2013', '26/9/2013', '28/9/2013', '30/9/2013', '10/02/2013', '10/04/2013',\
           '10/06/2013', '10/08/2010', '10/10/2013', '10/12/2013']

# creating dtaframe of the result
df = pd.DataFrame(from_db, columns = cols)
display(df)
# Out:
# Query reading was successful
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 545   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 546   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 547   532874347   Casual  Average     4.7     M  Summer     v-neck
# 548   655464934   Casual  Average     4.6     L  winter  boat-neck
# 549   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration PatternType  \
# 0      sleevless    empire           None     chiffon     ruffles      animal
# 1          Petal   natural     microfiber        None     ruffles      animal
# 2           full   natural       polyster        None        None       print
# 3           full   natural           silk     chiffon  embroidary       print
# 4      butterfly   natural  chiffonfabric     chiffon         bow         dot
# ..           ...       ...            ...         ...         ...         ...
# 545         full    empire         cotton        None        None        None
# 546         full    empire         cotton        None        None        None
# 547         full    empire         cotton        None        lace       solid
# 548    sleevless    empire           silk  broadcloth    applique       print
# 549        short    empire         cotton    Corduroy        lace       solid
#
#      Recommendation    Dress_ID  29/8/2013  31/8/2013  09/02/2013  09/04/2013  \
# 0                 1  1006032852       2114       2274        2491        2660
# 1                 0  1212192089        151        275         570         750
# 2                 0  1190380701          6          7           7           7
# 3                 1   966005983       1005       1128        1326        1455
# 4                 0   876339541        996       1175        1304        1396
# ..              ...         ...        ...        ...         ...         ...
# 545               0   722565148          0          0           0         875
# 546               0   722565148        856        882         882         868
# 547               1   532874347          0          0           0         734
# 548               1   655464934          0          0           0         254
# 549               0   919930954          0          0           0         538
#
#      09/06/2013  09/08/2013  09/10/2013 09/12/2013 14/9/2013 16/9/2013  \
# 0          2727        2887        2930       3119      3204      3277
# 1           813        1066        1164       1558      1756      1878
# 2             8           8           9         10        10        10
# 3          1507        1621        1637       1723      1746      1783
# 4          1432        1559        1570       1638      1655      1681
# ..          ...         ...         ...        ...       ...       ...
# 545         866         861         854        850       844       841
# 546         866         861         854        850       845       841
# 547         728         726         715        694       690       686
# 548         259         261         263        268       270       272
# 549         545         558         563        578       585       590
#
#     18/9/2013 20/9/2013 22/9/2013  24/9/2013  26/9/2013  28/9/2013  30/9/2013  \
# 0        3321      3386      3479       3554     3624.0       3706     3746.0
# 1        1985      2106      2454       2710     2942.0       3258     3354.0
# 2          10        10        11         11       11.0         11       11.0
# 3        1796      1812      1845       1878     1892.0       1914     1924.0
# 4        1743      1824      1919       2032     2156.0       2252     2312.0
# ..        ...       ...       ...        ...        ...        ...        ...
# 545       845       851       864        859      866.0        882      888.0
# 546       849       852       864        859        0.0        882        0.0
# 547       674       665       658        616      597.0        586      569.0
# 548       272       264       264        257      256.0        255      254.0
# 549       599       605       619        628      632.0        639      645.0
#
#      10/02/2013  10/04/2013  10/06/2013  10/08/2010  10/10/2013  10/12/2013
# 0        3795.0      3832.0        3897      3923.0      3985.0        4048
# 1        3475.0      3654.0        3911      4024.0      4125.0        4277
# 2          11.0        11.0          11        11.0        11.0          11
# 3        1929.0      1941.0        1952      1955.0      1959.0        1963
# 4        2387.0      2459.0        2544      2614.0      2693.0        2736
# ..          ...         ...         ...         ...         ...         ...
# 545       895.0       898.0         906       913.0       919.0         931
# 546         0.0         0.0         906         0.0         0.0         931
# 547       561.0       555.0         551       546.0       535.0         520
# 548       253.0       250.0         249       249.0       249.0         248
# 549       651.0       655.0         660       668.0       674.0         680
#
# [550 rows x 38 columns]

# %%
# Finding number of unique dresses we have based on 'Dress_ID'

# query
q = 'SELECT COUNT(DISTINCT Dress_ID) AS "Number of dresses" FROM attributes;'

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    
# creating column names
cols = ['Number of Unique dresses']

# creating dtaframe of the result
df = pd.DataFrame(from_db, columns = cols)
display(df)
# Out:
# Query reading was successful
#    Number of Unique dresses
# 0                       475

# %%
# Finding number of unique dresses we having 'Recommendation' as 0

# query
q = 'SELECT COUNT(*) AS "Number of results" FROM attributes WHERE Recommendation = 0;'

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    
# creating column names
cols = ['Number of dresses with recommendation as 0']

# creating dtaframe of the result
df = pd.DataFrame(from_db, columns = cols)
display(df)
# Out:
# Query reading was successful
#    Number of dresses with recommendation as 0
# 0                                         290

# %%
# finding out total dress sale based on 'Dress_ID' for each 'Dress_ID'.

q = """
SELECT DISTINCT
    Dress_ID,
    SUM(`29/8/2013` + `31/8/2013` + `29/8/2013` + `31/8/2013` + `09/02/2013` + `09/04/2013` + `09/06/2013` + `09/08/2013` +\
    `09/10/2013` + `09/12/2013` + `14/9/2013` + `16/9/2013` + `18/9/2013` + `20/9/2013` + `22/9/2013` + `24/9/2013` + \
    `26/9/2013` + `28/9/2013` + `30/9/2013` + `10/02/2013` + `10/04/2013` + `10/06/2013` + `10/08/2010` + `10/10/2013` + \
    `10/12/2013`) AS Total_sales
FROM
    sales AS s
GROUP BY s.Dress_ID;
"""

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    
# creating column names
cols = ['Dress_ID', 'Total_sales']

# creating dtaframe of the result
df = pd.DataFrame(from_db, columns = cols)
display(df)
# Out:
# Query reading was successful
#        Dress_ID  Total_sales
# 0    1006032852      80367.0
# 1    1212192089      52682.0
# 2    1190380701        236.0
# 3     966005983      41824.0
# 4     876339541      46248.0
# ..          ...          ...
# 470   990559192       1427.0
# 471   713391965       8915.0
# 472   532874347      12606.0
# 473   655464934       5167.0
# 474   919930954      12312.0
#
# [475 rows x 2 columns]

# %%
# finding out total dress sale based on 'Dress_ID' for each 'Dress_ID'.

q = """
SELECT DISTINCT
    Dress_ID,
    SUM(`29/8/2013` + `31/8/2013` + `29/8/2013` + `31/8/2013` + `09/02/2013` + `09/04/2013` + `09/06/2013` + `09/08/2013` +\
    `09/10/2013` + `09/12/2013` + `14/9/2013` + `16/9/2013` + `18/9/2013` + `20/9/2013` + `22/9/2013` + `24/9/2013` + \
    `26/9/2013` + `28/9/2013` + `30/9/2013` + `10/02/2013` + `10/04/2013` + `10/06/2013` + `10/08/2010` + `10/10/2013` + \
    `10/12/2013`) AS Total_sales
FROM
    sales AS s
GROUP BY s.Dress_ID ORDER BY Total_sales DESC;
"""

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    
# creating column names
cols = ['Dress_ID', 'Total_sales']

# creating dtaframe of the result
df = pd.DataFrame(from_db, columns = cols)



# finding the 3rd highest value
df.loc[2]
# Out:
# Query reading was successful
# Dress_ID       749031896.0
# Total_sales        80389.0
# Name: 2, dtype: float64

# %% [markdown]
# #### MongoDB:

# %%
# converting to json file

df3 = pd.read_csv('datasets/attributes.csv')


df3.to_json('F:\\Machine Learning\\INeuron_FSDS\\Live Classes\\database exercise\\datasets\\attributes.json')

# %%
df_json = pd.read_json('datasets/attributes.json')
df_json.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire           None    chiffon     ruffles       animal               1
# 1   natural     microfiber       None     ruffles       animal               0
# 2   natural       polyster       None        None        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
# importing the library
import pymongo

# %%
# connecting with the server
try:
    client = pymongo.MongoClient("mongodb+srv://ineuron:Project1@cluster0.rp4qzrr.mongodb.net/?retryWrites=true&w=majority")
except Exception as e:
    print(e)
else:
    print("Connection to MongoDB server is successful.")
# Out:
# Connection to MongoDB server is successful.

# %%
# creating database and collection

db = client["db_exercise"]
coll = db['attributes']

# %%
try:
    import json
except ImportError:
    import simplejson as json

# %%
# Inserting the data into the collection

try:
    with open('datasets/attributes.json') as file:
        file_data = json.load(file)
        
        coll.insert_many([file_data])
except Exception as e:
    print(e)
else:
    print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
# Now to read the data

# importing the library to take care of the objectid created by mongodb
import bson.json_util as json_util

results = coll.find()
try:
    for result in results:
        data = json_util.dumps(result)
        df = pd.read_json(data, orient='index')
except Exception as e:
    print(e)
else:
    display(df)
# Out:
#                                     $oid           0           1           2  \
# _id             62e151f03db1e07327eb36e7         NaN         NaN         NaN
# Dress_ID                             NaN  1006032852  1212192089  1190380701
# Style                                NaN        Sexy      Casual     vintage
# Price                                NaN         Low         Low        High
# Rating                               NaN         4.6         0.0         0.0
# Size                                 NaN           M           L           L
# Season                               NaN      Summer      Summer      Automn
# NeckLine                             NaN      o-neck      o-neck      o-neck
# SleeveLength                         NaN   sleevless       Petal        full
# waiseline                            NaN      empire     natural     natural
# Material                             NaN        None  microfiber    polyster
# FabricType                           NaN     chiffon        None        None
# Decoration                           NaN     ruffles     ruffles        None
# Pattern Type                         NaN      animal      animal       print
# Recommendation                       NaN           1           0           0
#
#                          3              4           5           6           7  \
# _id                    NaN            NaN         NaN         NaN         NaN
# Dress_ID         966005983      876339541  1068332458  1220707172  1219677488
# Style                Brief           cute    bohemian      Casual     Novelty
# Price              Average            Low         Low     Average     Average
# Rating                 4.6            4.5         0.0         0.0         0.0
# Size                     L              M           M          XL        free
# Season              Spring         Summer      Summer      Summer      Automn
# NeckLine            o-neck         o-neck      v-neck      o-neck      o-neck
# SleeveLength          full      butterfly   sleevless        full       short
# waiseline          natural        natural      empire        None     natural
# Material              silk  chiffonfabric        None      cotton    polyster
# FabricType         chiffon        chiffon        None        None  broadcloth
# Decoration      embroidary            bow        None        None        lace
# Pattern Type         print            dot       print       solid        None
# Recommendation           1              0           0           0           0
#
#                          8  ...        490        491         492        493  \
# _id                    NaN  ...        NaN        NaN         NaN        NaN
# Dress_ID        1113094204  ...  641665398  964917582   859922576  817353671
# Style                Flare  ...     Casual     Casual        cute   bohemian
# Price              Average  ...        Low    Average     Average        Low
# Rating                 0.0  ...        4.8        5.0         4.6        4.6
# Size                  free  ...       free          L           M       free
# Season              Spring  ...     winter     Summer      Spring     Summer
# NeckLine            v-neck  ...    bowneck     o-neck      o-neck     o-neck
# SleeveLength         short  ...       full  sleevless  halfsleeve  sleevless
# waiseline           empire  ...    natural    natural     natural    natural
# Material            cotton  ...   polyster     cotton     acrylic     cotton
# FabricType      broadcloth  ...    chiffon       None     chiffon    chiffon
# Decoration         beading  ...        bow       None        None       none
# Pattern Type         solid  ...      solid       None        None      solid
# Recommendation           1  ...          0          1           0          1
#
#                        494        495        496        497         498  \
# _id                    NaN        NaN        NaN        NaN         NaN
# Dress_ID         990559192  713391965  722565148  532874347   655464934
# Style                Brief     Casual       Sexy     Casual      Casual
# Price              Average        Low        Low    Average     Average
# Rating                 4.7        4.7        4.3        4.7         4.6
# Size                     M          M       free          M           L
# Season              winter     Spring     Summer     Summer      winter
# NeckLine            o-neck     o-neck     o-neck     v-neck   boat-neck
# SleeveLength    halfsleeve       full       full       full   sleevless
# waiseline          natural    natural     empire     empire      empire
# Material           acrylic   polyster     cotton     cotton        silk
# FabricType         chiffon       None       None       None  broadcloth
# Decoration            None       None       None       lace    applique
# Pattern Type       striped      solid       None      solid       print
# Recommendation           0          1          0          1           1
#
#                       499
# _id                   NaN
# Dress_ID        919930954
# Style              Casual
# Price                 Low
# Rating                4.4
# Size                 free
# Season             Summer
# NeckLine           v-neck
# SleeveLength        short
# waiseline          empire
# Material           cotton
# FabricType       Corduroy
# Decoration           lace
# Pattern Type        solid
# Recommendation          0
#
# [15 rows x 501 columns]
