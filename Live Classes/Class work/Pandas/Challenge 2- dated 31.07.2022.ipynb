# %% [raw]
# ### Task 1 - Fitbit Dataset
#
# 1. Read this dataset in pandas , mysql and mongodb.
#
# 2. While creating a table in mysql don't use manual approach instead use an automation to create a table in mysql.
#
# - `hint` - use csvkit library to automate this task and to load a data in bulk in you mysql.
#
# 3. Convert all the dates avaible in dataset to timestamp format in pandas and in sql convert it in date format.
#
# 4. Find out number of unique IDs in the dataset.
#
# 5. Which ID is one of the active id in the whole dataset.
#
# 6. How many of them have not logged there activity? (find out in terms of number of ids)
#
# 7. Find out who is the laziest person ID that we have in dataset.
#
# 8. Explore over internet that how much calory burn is required for a healthy person and find out how many healthy persons we have in our dataset.
#
# 9. How many person are not a regular person with respect to activity try to find out those.
#
# 10. Who is the third most active person in this dataset find out those in pandas and in sql both.
#
# 11. Who is the 5th most laziest person avilable in dataset find it out.
#
# 12. What is a total acumulative calories burn for a person find out.

# %% [raw]
# ### Task 2 - Superstore_USA
#
# 1. Load this data in sql and in pandas with a relation in sql.(Create Primary key, Foreign key)
#
# 2. While loading this data you don't have to create a table manually you can use any automated approach to create a table and load a data in bulk in table.
#
# 3. Find out how many return that we have recived and with a product id.
#
# 4. Try  to join order and return data both in sql and pandas.
#
# 5. Try to find out how many unique customers that we have.
#
# 6. Try to find out in how many regions we are selling a product and who is a manager for each respective regions.
#
# 7. Find out how many different shipement modes that we have and what is a percentage usablity of all the shipment mode with respect to the dataset.
#
# 8. Create a new coulmn and try to find out a diffrence between order date and shipment date.
#
# 9. Based on question number 8 find out for which order id we have shipment duration more than 10 days.
#
# 10. Try to find out a list of returned order where sihpment duration was more than 15 days and find out that region manager as well.
#
# 11. Gorup by region and find out which region is more profitable.
#
# 12. Try to find out overall in which country we are giving more didscount.
#
# 13. Give me a list of unique postal codes.
#
# 14. Which customer segement is more profitalble find it out.
#
# 15. Try to find out the 10th most loss making product catagory.
#
# 16. Try to find out 10 top  product with highest margins.

# %% [raw]
# submit your git link for the same
#
# you have to submit this task by next Friday 5th 11PM IST  to respective mail id
# sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %% [markdown]
# ## FitBit Dataset:

# %%
# import the libraries

import pandas as pd
import mysql.connector as conn
from mysql.connector import Error
from sqlalchemy import create_engine
import pymongo
import bson.json_util as json_util       # to read data from mongodb to take care of the ObjectId

# %% [markdown]
# #### 1. Read this dataset in pandas , mysql and mongodb.
#
# #### 2. While creating a table in mysql don't use manual approach instead use an automation to create a table in mysql.

# %%
# Reading in Pandas

df = pd.read_csv('dataset/FitBit data.csv')
pd.set_option('display.max_columns', None)

df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
# checking datatypes

df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
# Changing column ActivityDate to date as because in mysql the default date format is 'YYYY-MM-DD'

df['ActivityDate'] = pd.to_datetime(df['ActivityDate'], yearfirst=True)

df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
# checking again dtypes

df.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %% [markdown]
# ##### MySQL part

# %%
# Creating functions for MySQL

# Server connection
def create_server_connection(host_name, user_name, user_pwd):
    connection = None
    try:
        connection = conn.connect(host=host_name, user=user_name, passwd=user_pwd)

        print("Connection to MySQL is successful.")

    except Error as err:
        print(f"Error is: {err}")

    else:
        return connection
    

    
# Creating database
def create_database(connection, query):
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        print("Database created successfully")

    except Error as err:
        print(f"Error is: {err}")
        

        
# Connecting to the database
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = conn.connect(host=host_name, user=user_name, passwd=user_password, database=db_name)
        print("Connected to the Database Successfully")

    except Error as err:
        print(f"Error is: {err}")

    else:
        return connection
 


    
# Executing query
def execute_query(connection, query):
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        connection.commit()
        print("Query execution was successful")

    except Error as err:
        print(f"Error is: {err}")
        

        
        
# Showing query results
def read_query(connection, query):
    cursor = connection.cursor()
    result = None

    try:
        cursor.execute(query)
        result = cursor.fetchall()
        print("Query reading was successful")

    except Error as err:
        print(f"Error: {err}")

    else:
        return result

# %%
# Connection with MySQL

host = "localhost"
user = "root"
pw = "Password"

connection = create_server_connection(host, user, pw)
# Out:
# Connection to MySQL is successful.

# %%
# Creating the database

query = "CREATE DATABASE IF NOT EXISTS panda_exercise"
create_database(connection, query)
# Out:
# Database created successfully

# %%
# Connecting with the database

db = "panda_exercise"

db_connection = create_db_connection(host, user, pw, db)
# Out:
# Connected to the Database Successfully

# %%
# Creating table and inserting data

engine = create_engine("mysql+pymysql://root:Password@localhost:3306/panda_exercise")


try:
    df.to_sql(name='fitbit', con=engine, index=False, if_exists='replace')
except Exception as e:
    print("Error is: ", e)
else:
    print("Query is Successful")
# Out:
# Query is Successful

# %%
# Reading from SQL

# query
q = 'SELECT * FROM fitbit;'

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    
# creating column names
cols = ['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',\
       'LoggedActivitiesDistance', 'VeryActiveDistance',\
       'ModeratelyActiveDistance', 'LightActiveDistance',\
       'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',\
       'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

# creating dtaframe of the result
df1 = pd.DataFrame(from_db, columns = cols)
display(df1)
# Out:
# Query reading was successful
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %% [markdown]
# ##### MongoDB part

# %%
pwd
# Out:
# 'F:\\Machine Learning\\INeuron_FSDS\\Live Classes\\Pandas'

# %%
# convering data to a json file

df2 = pd.read_csv('dataset/FitBit data.csv')

df2.to_json('F:\\Machine Learning\\INeuron_FSDS\\Live Classes\\Pandas\\dataset\\fitbit.json')

# %%
# connecting with the server
try:
    client = pymongo.MongoClient("mongodb+srv://ineuron:Project1@cluster0.rp4qzrr.mongodb.net/?retryWrites=true&w=majority")
except Exception as e:
    print(e)
else:
    print("Connection to MongoDB server is successful.")
# Out:
# Connection to MongoDB server is successful.

# %%
# creating database and collection

db = client["panda_exercise"]
coll = db['fitbit']

# %%
try:
    import json
except ImportError:
    import simplejson as json

# %%
# Inserting the data into the collection
try:
    with open('dataset/fitbit.json') as file:
        file_data = json.load(file)
        
        coll.insert_many([file_data])
except Exception as e:
    print(e)
else:
    print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
# Now to read the data

results = coll.find()
try:
    for result in results:
        data = json_util.dumps(result)
        df3 = pd.read_json(data, orient='index')
except Exception as e:
    print(e)
else:
    display(df3)
# Out:
#                                               $oid           0           1  \
# _id                       62e8bb15c0968bbb4d1a02b0         NaN         NaN
# Id                                             NaN  1503960366  1503960366
# ActivityDate                                   NaN   3/25/2016   3/26/2016
# TotalSteps                                     NaN       11004       17609
# TotalDistance                                  NaN        7.11       11.55
# TrackerDistance                                NaN        7.11       11.55
# LoggedActivitiesDistance                       NaN         0.0         0.0
# VeryActiveDistance                             NaN        2.57        6.92
# ModeratelyActiveDistance                       NaN        0.46        0.73
# LightActiveDistance                            NaN        4.07        3.91
# SedentaryActiveDistance                        NaN         0.0         0.0
# VeryActiveMinutes                              NaN          33          89
# FairlyActiveMinutes                            NaN          12          17
# LightlyActiveMinutes                           NaN         205         274
# SedentaryMinutes                               NaN         804         588
# Calories                                       NaN        1819        2154
#
#                                    2           3           4           5  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1503960366  1503960366  1503960366  1503960366
# ActivityDate               3/27/2016   3/28/2016   3/29/2016   3/30/2016
# TotalSteps                     12736       13231       12041       10970
# TotalDistance                   8.53        8.93        7.85        7.16
# TrackerDistance                 8.53        8.93        7.85        7.16
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              4.66        3.19        2.16        2.36
# ModeratelyActiveDistance        0.16        0.79        1.09        0.51
# LightActiveDistance             3.71        4.95        4.61        4.29
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 56          39          28          30
# FairlyActiveMinutes                5          20          28          13
# LightlyActiveMinutes             268         224         243         223
# SedentaryMinutes                 605        1080         763        1174
# Calories                        1944        1932        1886        1820
#
#                                    6           7           8           9  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1503960366  1503960366  1503960366  1503960366
# ActivityDate               3/31/2016    4/1/2016    4/2/2016    4/3/2016
# TotalSteps                     12256       12262       11248       10016
# TotalDistance                   7.86        7.87        7.25        6.37
# TrackerDistance                 7.86        7.87        7.25        6.37
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              2.29        3.32         3.0        0.91
# ModeratelyActiveDistance        0.49        0.83        0.45        1.28
# LightActiveDistance             5.04        3.64        3.74        4.18
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 33          47          40          15
# FairlyActiveMinutes               12          21          11          30
# LightlyActiveMinutes             239         200         244         314
# SedentaryMinutes                 820         866         636         655
# Calories                        1889        1868        1843        1850
#
#                                   10          11          12          13  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1503960366  1503960366  1503960366  1503960366
# ActivityDate                4/4/2016    4/5/2016    4/6/2016    4/7/2016
# TotalSteps                     14557       14844       11974       10198
# TotalDistance                    9.8        9.73        7.67        6.44
# TrackerDistance                  9.8        9.73        7.67        6.44
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              3.39        2.94        2.04         1.2
# ModeratelyActiveDistance         0.7        0.76        0.48        0.79
# LightActiveDistance             5.69        6.04        5.15        4.45
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 43          36          27          17
# FairlyActiveMinutes               18          18          12          20
# LightlyActiveMinutes             285         341         228         195
# SedentaryMinutes                 757         736        1173        1208
# Calories                        2030        2083        1861        1755
#
#                                   14          15          16          17  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1503960366  1503960366  1503960366  1503960366
# ActivityDate                4/8/2016    4/9/2016   4/10/2016   4/11/2016
# TotalSteps                     12521       12432       10057       10990
# TotalDistance                   7.94         8.1        6.98        7.26
# TrackerDistance                 7.94         8.1        6.98        7.26
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              3.31        2.59         4.0        2.04
# ModeratelyActiveDistance         0.9        0.59        0.49        0.57
# LightActiveDistance             3.74        4.92        2.48        4.65
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 46          32          44          26
# FairlyActiveMinutes               22          15          13          14
# LightlyActiveMinutes             212         248         168         216
# SedentaryMinutes                1160         738         737         855
# Calories                        1895        1883        1755        1811
#
#                                   18          19          20          21  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1503960366  1624580081  1624580081  1624580081
# ActivityDate               4/12/2016   3/25/2016   3/26/2016   3/27/2016
# TotalSteps                       224        1810         815        1985
# TotalDistance                   0.14        1.18        0.53        1.29
# TrackerDistance                 0.14        1.18        0.53        1.29
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             0.13        1.13        0.53        1.28
# SedentaryActiveDistance          0.0        0.01         0.0        0.01
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes               9         121          47         112
# SedentaryMinutes                  32        1319        1393        1328
# Calories                          50        1373        1264        1350
#
#                                   22          23          24          25  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1624580081  1624580081  1624580081  1624580081
# ActivityDate               3/28/2016   3/29/2016   3/30/2016   3/31/2016
# TotalSteps                      1905        1552        1675        4506
# TotalDistance                   1.24        1.01        1.09        2.93
# TrackerDistance                 1.24        1.01        1.09        2.93
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0        0.51
# ModeratelyActiveDistance         0.0         0.0         0.0        0.27
# LightActiveDistance             1.24         1.0        1.09        2.15
# SedentaryActiveDistance          0.0         0.0         0.0        0.01
# VeryActiveMinutes                  0           0           0           7
# FairlyActiveMinutes                0           0           0           4
# LightlyActiveMinutes              95          66          84         144
# SedentaryMinutes                1345        1374        1356        1285
# Calories                        1342        1300        1313        1498
#
#                                   26          27          28          29  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1624580081  1624580081  1624580081  1624580081
# ActivityDate                4/1/2016    4/2/2016    4/3/2016    4/4/2016
# TotalSteps                      9218        1556        2910       18464
# TotalDistance                   5.99        1.01        1.89        12.0
# TrackerDistance                 5.99        1.01        1.89        12.0
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             5.97        1.01        1.88        12.0
# SedentaryActiveDistance         0.01        0.01        0.01         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             221          88         157         270
# SedentaryMinutes                1219        1352        1283        1170
# Calories                        1541        1327        1452        1574
#
#                                   30          31          32          33  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1624580081  1624580081  1624580081  1624580081
# ActivityDate                4/5/2016    4/6/2016    4/7/2016    4/8/2016
# TotalSteps                      1335        1004        1111        6344
# TotalDistance                   0.87        0.65        0.72        4.12
# TrackerDistance                 0.87        0.65        0.72        4.12
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             0.87        0.65        0.72         4.1
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes              74          55          54         143
# SedentaryMinutes                1366        1385        1386        1297
# Calories                        1308        1276        1278        1409
#
#                                   34          35          36          37  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1624580081  1624580081  1624580081  1624580081
# ActivityDate                4/9/2016   4/10/2016   4/11/2016   4/12/2016
# TotalSteps                      3572        3910       10000        6627
# TotalDistance                   2.32        2.54         6.5        4.31
# TrackerDistance                 2.32        2.54         6.5        4.31
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0        0.47         0.0         0.0
# ModeratelyActiveDistance         0.0        0.25         0.0         0.0
# LightActiveDistance             2.29        1.81         6.5        4.31
# SedentaryActiveDistance         0.03        0.01         0.0         0.0
# VeryActiveMinutes                  0           7           0           0
# FairlyActiveMinutes                0           7           0           0
# LightlyActiveMinutes             122         186         172          89
# SedentaryMinutes                1318        1240        1268         604
# Calories                        1370        1555        1469         706
#
#                                   38          39          40          41  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1644430081  1644430081  1644430081  1644430081
# ActivityDate                4/1/2016    4/2/2016    4/3/2016    4/4/2016
# TotalSteps                      4636       20237       12912        2819
# TotalDistance                   3.41       14.71        9.41        2.05
# TrackerDistance                 3.41       14.71        9.41        2.05
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0        2.57        4.83        0.31
# ModeratelyActiveDistance        0.78         6.4        0.77        0.17
# LightActiveDistance              2.6        5.73        3.79        1.56
# SedentaryActiveDistance         0.03        0.01        0.03        0.01
# VeryActiveMinutes                  0          34          59           4
# FairlyActiveMinutes               16         141          16           4
# LightlyActiveMinutes             586         347         283          87
# SedentaryMinutes                 838         918        1082        1345
# Calories                        3323        4029        3436        2444
#
#                                   42          43          44          45  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1644430081  1644430081  1644430081  1644430081
# ActivityDate                4/5/2016    4/6/2016    4/7/2016    4/8/2016
# TotalSteps                      9921        8046       11166        7842
# TotalDistance                   7.21        5.85        8.12         5.7
# TrackerDistance                 7.21        5.85        8.12         5.7
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              0.34        1.29        0.21        0.48
# ModeratelyActiveDistance        1.52        2.12        2.41        2.41
# LightActiveDistance             5.36        2.45         5.5        2.81
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  5          18           3           7
# FairlyActiveMinutes               35          41          58          43
# LightlyActiveMinutes             219         137         230         161
# SedentaryMinutes                1181        1244        1149        1229
# Calories                        3098        2925        3202        2928
#
#                                   46          47          48          49  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1644430081  1644430081  1844505072  1844505072
# ActivityDate                4/9/2016   4/10/2016    4/1/2016    4/2/2016
# TotalSteps                     13840        1329        6847        5367
# TotalDistance                  10.06        0.97        4.53        3.55
# TrackerDistance                10.06        0.97        4.53        3.55
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              1.31         0.0        0.61         0.0
# ModeratelyActiveDistance        3.72         0.0        0.37         0.0
# LightActiveDistance             5.03        0.97        3.55        3.55
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 18           0           9           0
# FairlyActiveMinutes               81           0           9           0
# LightlyActiveMinutes             192          35         251         263
# SedentaryMinutes                1149         207        1171        1177
# Calories                        3290         489        1969        1889
#
#                                   50          51          52          53  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1844505072  1844505072  1844505072  1844505072
# ActivityDate                4/3/2016    4/4/2016    4/5/2016    4/6/2016
# TotalSteps                      2841           0           0           7
# TotalDistance                   1.88         0.0         0.0         0.0
# TrackerDistance                 1.88         0.0         0.0         0.0
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             1.88         0.0         0.0         0.0
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             136           0           0           1
# SedentaryMinutes                1114         669        1440        1439
# Calories                        1636        1347        1347        1349
#
#                                   54          55          56          57  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1844505072  1844505072  1844505072  1844505072
# ActivityDate                4/7/2016    4/8/2016    4/9/2016   4/10/2016
# TotalSteps                      6344        5316        4979        6556
# TotalDistance                   4.19        3.51        3.29        4.34
# TrackerDistance                 4.19        3.51        3.29        4.34
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             4.19        3.51        3.29        4.33
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             290         221         184         305
# SedentaryMinutes                1150        1219         620         810
# Calories                        1965        1824        1807        1971
#
#                                   58          59          60          61  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1844505072  1844505072  1927972279  1927972279
# ActivityDate               4/11/2016   4/12/2016    4/1/2016    4/2/2016
# TotalSteps                      5430           0        4317        5662
# TotalDistance                   3.59         0.0        2.99        3.92
# TrackerDistance                 3.59         0.0        2.99        3.92
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0        0.37         0.0
# LightActiveDistance             3.59         0.0        2.62        3.92
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0          11           0
# LightlyActiveMinutes             251           0         192         267
# SedentaryMinutes                1189         426         854         858
# Calories                        1888         399        2590        2783
#
#                                   62          63          64          65  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1927972279  1927972279  1927972279  1927972279
# ActivityDate                4/3/2016    4/4/2016    4/5/2016    4/6/2016
# TotalSteps                      3198        2352        2234        1259
# TotalDistance                   2.21        1.63        1.55        0.87
# TrackerDistance                 2.21        1.63        1.55        0.87
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             2.21        1.63        1.55        0.87
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             146         128         108          73
# SedentaryMinutes                1183         829         912         938
# Calories                        2449        2380        2344        2202
#
#                                   66          67          68          69  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1927972279  1927972279  1927972279  1927972279
# ActivityDate                4/7/2016    4/8/2016    4/9/2016   4/10/2016
# TotalSteps                       768         519        2523        2105
# TotalDistance                   0.53        0.36        1.75        1.46
# TrackerDistance                 0.53        0.36        1.75        1.46
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0        0.37         0.0
# LightActiveDistance             0.53        0.36        1.38        1.46
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           9           0
# LightlyActiveMinutes              43          34         134         139
# SedentaryMinutes                1397        1406        1250         805
# Calories                        2130        2088        2443        2442
#
#                                   70          71          72          73  \
# _id                              NaN         NaN         NaN         NaN
# Id                        1927972279  1927972279  2022484408  2022484408
# ActivityDate               4/11/2016   4/12/2016    4/1/2016    4/2/2016
# TotalSteps                      1209          24       13603        5477
# TotalDistance                   0.84        0.02         9.6        3.84
# TrackerDistance                 0.84        0.02         9.6        3.84
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0        5.46         0.0
# ModeratelyActiveDistance         0.0         0.0        0.63         0.0
# LightActiveDistance             0.84        0.02        3.51        3.84
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0          72           0
# FairlyActiveMinutes                0           0          16           0
# LightlyActiveMinutes              73           3         213         237
# SedentaryMinutes                 842         161        1139        1203
# Calories                        2255         942        2645        2040
#
#                                   74          75          76          77  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2022484408  2022484408  2022484408  2022484408
# ActivityDate                4/3/2016    4/4/2016    4/5/2016    4/6/2016
# TotalSteps                     11144       15313       10805       15392
# TotalDistance                   7.82        11.0        7.59       10.93
# TrackerDistance                 7.82        11.0        7.59       10.93
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              1.79        5.02        0.72        3.43
# ModeratelyActiveDistance        0.89        1.29        0.98        1.75
# LightActiveDistance             5.14        4.69        5.89        5.75
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 25          62          36          47
# FairlyActiveMinutes               22          19          37          42
# LightlyActiveMinutes             279         233         298         258
# SedentaryMinutes                1114        1126        1069        1093
# Calories                        2395        2581        2735        2733
#
#                                   78          79          80          81  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2022484408  2022484408  2022484408  2022484408
# ActivityDate                4/7/2016    4/8/2016    4/9/2016   4/10/2016
# TotalSteps                     18247       13023       16267       10005
# TotalDistance                  13.83        9.26       12.59        7.02
# TrackerDistance                13.83        9.26       12.59        7.02
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              7.11        3.23        5.75        0.08
# ModeratelyActiveDistance        2.21        0.56        0.47        1.05
# LightActiveDistance             4.51        5.47        6.37         5.9
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 72          40          44           1
# FairlyActiveMinutes               62          12          16          23
# LightlyActiveMinutes             252         296         302         339
# SedentaryMinutes                1054        1092        1078        1077
# Calories                        3021        2577        2811        2458
#
#                                   82          83          84          85  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2022484408  2022484408  2026352035  2026352035
# ActivityDate               4/11/2016   4/12/2016    4/1/2016    4/2/2016
# TotalSteps                     10106        6717        2605        1229
# TotalDistance                   7.09        4.72        1.62        0.76
# TrackerDistance                 7.09        4.72        1.62        0.76
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              1.21        3.23         0.0         0.0
# ModeratelyActiveDistance        0.56        0.22         0.0         0.0
# LightActiveDistance             5.33        1.27        1.62        0.76
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 41          41           0           0
# FairlyActiveMinutes               16           5           0           0
# LightlyActiveMinutes             272          67         166          69
# SedentaryMinutes                1111         551         729         795
# Calories                        2568        1140        1407        1237
#
#                                   86          87          88          89  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2026352035  2026352035  2026352035  2026352035
# ActivityDate                4/3/2016    4/4/2016    4/5/2016    4/6/2016
# TotalSteps                      2308        6679        5645        3180
# TotalDistance                   1.43        4.14         3.5        1.97
# TrackerDistance                 1.43        4.14         3.5        1.97
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             1.43        4.14         3.5        1.97
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             115         263         248         185
# SedentaryMinutes                 720         644         621         738
# Calories                        1330        1583        1538        1421
#
#                                   90          91          92          93  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2026352035  2026352035  2026352035  2026352035
# ActivityDate                4/7/2016    4/8/2016    4/9/2016   4/10/2016
# TotalSteps                      2767        3762        3098        5142
# TotalDistance                   1.72        2.33        1.92        3.19
# TrackerDistance                 1.72        2.33        1.92        3.19
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             1.72        2.33        1.92        3.19
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             170         173         185         230
# SedentaryMinutes                 673         719         700         654
# Calories                        1392        1425        1413        1515
#
#                                   94          95          96          97  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2026352035  2026352035  2320127002  2320127002
# ActivityDate               4/11/2016   4/12/2016    4/1/2016    4/2/2016
# TotalSteps                      3279        1019           0           0
# TotalDistance                   2.03        0.63         0.0         0.0
# TrackerDistance                 2.03        0.63         0.0         0.0
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance             2.03        0.63         0.0         0.0
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes             164          64           0           0
# SedentaryMinutes                 694         223        1440        1440
# Calories                        1405         600        1324        1324
#
#                                   98          99         100         101  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2320127002  2320127002  2320127002  2320127002
# ActivityDate                4/3/2016    4/4/2016    4/5/2016    4/6/2016
# TotalSteps                         0           0        4931        6999
# TotalDistance                    0.0         0.0        3.32        4.72
# TrackerDistance                  0.0         0.0        3.32        4.72
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance              0.0         0.0        3.32        4.72
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes               0           0         175         320
# SedentaryMinutes                1440        1440        1265        1120
# Calories                        1324        1324        1708        1950
#
#                                  102         103         104         105  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2320127002  2320127002  2320127002  2320127002
# ActivityDate                4/7/2016    4/8/2016    4/9/2016   4/10/2016
# TotalSteps                      1846        3417        4863        2277
# TotalDistance                   1.24         2.3        3.28        1.53
# TrackerDistance                 1.24         2.3        3.28        1.53
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0        0.06         0.0
# ModeratelyActiveDistance         0.0         0.0        0.42         0.0
# LightActiveDistance             1.24         2.3         2.8        1.53
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           1           0
# FairlyActiveMinutes                0           0          11           0
# LightlyActiveMinutes              93         153         208         103
# SedentaryMinutes                1347        1287        1220        1337
# Calories                        1508        1625        1772        1530
#
#                                  106         107         108         109  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2320127002  2320127002  2347167796  2347167796
# ActivityDate               4/11/2016   4/12/2016   3/29/2016   3/30/2016
# TotalSteps                     11230        2098       10272       10533
# TotalDistance                   7.67        1.41        6.79         7.1
# TrackerDistance                 7.67        1.41        6.79         7.1
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              0.89         0.0        0.16        1.77
# ModeratelyActiveDistance        0.12         0.0        3.12        2.06
# LightActiveDistance             6.66        1.41         3.5        3.27
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 10           0           2          21
# FairlyActiveMinutes                2           0          58          35
# LightlyActiveMinutes             390          69         208         255
# SedentaryMinutes                1038         617         700         615
# Calories                        2206         790        2041        2187
#
#                                  110         111         112         113  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2347167796  2347167796  2347167796  2347167796
# ActivityDate               3/31/2016    4/1/2016    4/2/2016    4/3/2016
# TotalSteps                      6760        8328       15459        7485
# TotalDistance                   4.47        5.51       10.22        4.95
# TrackerDistance                 4.47        5.51       10.22        4.95
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0        3.59         0.0
# ModeratelyActiveDistance         0.0         2.0        0.81         0.0
# LightActiveDistance             4.47         3.5        5.82        4.95
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0          51           0
# FairlyActiveMinutes                0          33          16           0
# LightlyActiveMinutes             250         212         327         324
# SedentaryMinutes                 613         804         583         491
# Calories                        1929        1935        2438        2035
#
#                                  114         115         116         117  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2347167796  2347167796  2347167796  2347167796
# ActivityDate                4/4/2016    4/5/2016    4/6/2016    4/7/2016
# TotalSteps                     10254       10114       11107       10320
# TotalDistance                    6.8        6.82        7.34        6.85
# TrackerDistance                  6.8        6.82        7.34        6.85
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              1.42        1.64         0.9        0.68
# ModeratelyActiveDistance        1.23        0.48        2.76        1.23
# LightActiveDistance             4.16        4.68        3.68        4.94
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 21          18          14          15
# FairlyActiveMinutes               25           9          46          32
# LightlyActiveMinutes             231         269         196         315
# SedentaryMinutes                 638         696         759        1002
# Calories                        2099        2096        2058        2338
#
#                                  118         119         120         121  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2347167796  2347167796  2347167796  2347167796
# ActivityDate                4/8/2016    4/9/2016   4/10/2016   4/11/2016
# TotalSteps                     10209       16081       10078       10001
# TotalDistance                   6.75       10.63        6.83        6.61
# TrackerDistance                 6.75       10.63        6.83        6.61
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              0.16        1.25        1.02        0.33
# ModeratelyActiveDistance        0.35        1.82        0.12        2.93
# LightActiveDistance             6.23        7.56        5.69        3.36
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  2          16          12           5
# FairlyActiveMinutes                6          32           3          52
# LightlyActiveMinutes             316         401         303         196
# SedentaryMinutes                 711         970         463         788
# Calories                        2104        2488        2164        2009
#
#                                  122         123         124         125  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2347167796  2873212765  2873212765  2873212765
# ActivityDate               4/12/2016    4/1/2016    4/2/2016    4/3/2016
# TotalSteps                         0         890        2214        7640
# TotalDistance                    0.0         0.6        1.49        5.13
# TrackerDistance                  0.0         0.6        1.49        5.13
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0        0.19
# ModeratelyActiveDistance         0.0         0.0         0.0         0.8
# LightActiveDistance              0.0         0.6        1.49        4.15
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           3
# FairlyActiveMinutes                0           0           0          15
# LightlyActiveMinutes               0          41         197         315
# SedentaryMinutes                 425        1399        1243        1107
# Calories                         399        1335        1559        1845
#
#                                  126         127         128         129  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2873212765  2873212765  2873212765  2873212765
# ActivityDate                4/4/2016    4/5/2016    4/6/2016    4/7/2016
# TotalSteps                      9713        8432        7350        9353
# TotalDistance                   6.53        5.67        4.94        6.31
# TrackerDistance                 6.53        5.67        4.94        6.31
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              0.34         0.0         0.0        0.37
# ModeratelyActiveDistance        0.89         0.0         0.0        0.69
# LightActiveDistance             5.29        5.65        4.94        5.24
# SedentaryActiveDistance          0.0        0.01         0.0         0.0
# VeryActiveMinutes                  6           0           0           5
# FairlyActiveMinutes               24           0           0          17
# LightlyActiveMinutes             355         374         382         363
# SedentaryMinutes                1055        1066        1058        1055
# Calories                        2046        1953        1910        2035
#
#                                  130         131         132         133  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2873212765  2873212765  2873212765  2873212765
# ActivityDate                4/8/2016    4/9/2016   4/10/2016   4/11/2016
# TotalSteps                      7157       14103        5290        7497
# TotalDistance                   4.81        9.56        3.55        5.04
# TrackerDistance                 4.81        9.56        3.55        5.04
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0        3.02        0.04         0.0
# ModeratelyActiveDistance         0.0        0.41        0.34         0.0
# LightActiveDistance             4.81        6.14        3.17        5.04
# SedentaryActiveDistance          0.0        0.01         0.0         0.0
# VeryActiveMinutes                  0          46           1           0
# FairlyActiveMinutes                0           8           8           0
# LightlyActiveMinutes             380         288         251         357
# SedentaryMinutes                1060        1098        1180         882
# Calories                        1944        2257        1724        1741
#
#                                  134         135         136         137  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2873212765  2891001357  2891001357  2891001357
# ActivityDate               4/12/2016   3/29/2016   3/30/2016   3/31/2016
# TotalSteps                         0           0           0           0
# TotalDistance                    0.0         0.0         0.0         0.0
# TrackerDistance                  0.0         0.0         0.0         0.0
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance              0.0         0.0         0.0         0.0
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes                0           0           0           0
# LightlyActiveMinutes               0           0           0           0
# SedentaryMinutes                1440        1440        1440        1440
# Calories                           0        1920        1920        1920
#
#                                  138         139         140         141  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2891001357  2891001357  2891001357  2891001357
# ActivityDate                4/1/2016    4/2/2016    4/3/2016    4/4/2016
# TotalSteps                         0        4126           0           0
# TotalDistance                    0.0        3.22         0.0         0.0
# TrackerDistance                  0.0         0.0         0.0         0.0
# LoggedActivitiesDistance    4.828032    3.218688         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.0
# ModeratelyActiveDistance         0.0         0.0         0.0         0.0
# LightActiveDistance              0.0        3.22         0.0         0.0
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           0
# FairlyActiveMinutes              660           0           0           0
# LightlyActiveMinutes               0         720           0           0
# SedentaryMinutes                 780         720        1440        1440
# Calories                        4562        2881        1920        1920
#
#                                  142         143         144         145  \
# _id                              NaN         NaN         NaN         NaN
# Id                        2891001357  3372868164  3372868164  3372868164
# ActivityDate                4/5/2016    4/1/2016    4/2/2016    4/3/2016
# TotalSteps                      2063        5785        7625        4706
# TotalDistance                   1.61        3.95        5.23        3.21
# TrackerDistance                  0.0        3.95        5.23        3.21
# LoggedActivitiesDistance    1.609344         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0        1.68         0.0
# ModeratelyActiveDistance         0.0         0.0        0.04         0.0
# LightActiveDistance             1.61        3.91         3.5        3.21
# SedentaryActiveDistance          0.0        0.04        0.01         0.0
# VeryActiveMinutes                  0           0          24           0
# FairlyActiveMinutes                0           0           1           0
# LightlyActiveMinutes             630         311         341         299
# SedentaryMinutes                  99        1129        1074        1141
# Calories                        1144        1852        2069        1816
#
#                                  146         147         148         149  \
# ...
# VeryActiveDistance               0.0         1.0         5.7        0.54
# ModeratelyActiveDistance         0.0        0.91        0.93        1.55
# LightActiveDistance             1.28        1.51        2.51        1.46
# SedentaryActiveDistance          0.0        0.01         0.0         0.0
# VeryActiveMinutes                  0          15          47           8
# FairlyActiveMinutes                0          15          13          28
# LightlyActiveMinutes              94         107         150         148
# SedentaryMinutes                1346        1303        1230        1256
# Calories                        1607        1776        2162        1832
#
#                                  410         411         412         413  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8253242879  8253242879  8253242879  8378563200
# ActivityDate               4/10/2016   4/11/2016   4/12/2016    4/1/2016
# TotalSteps                      2545        1636           0       14179
# TotalDistance                   1.68        1.08         0.0       11.24
# TrackerDistance                 1.68        1.08         0.0       11.24
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0        6.23
# ModeratelyActiveDistance         0.0         0.0         0.0        1.06
# LightActiveDistance             1.67        1.08         0.0        3.96
# SedentaryActiveDistance         0.02         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0          73
# FairlyActiveMinutes                0           0           0          21
# LightlyActiveMinutes             126          86           0         195
# SedentaryMinutes                1314        1139        1440         719
# Calories                        1657        1377           0        3669
#
#                                  414         415         416         417  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8378563200  8378563200  8378563200  8378563200
# ActivityDate                4/2/2016    4/3/2016    4/4/2016    4/5/2016
# TotalSteps                      3358        9152       13935       12846
# TotalDistance                   2.66        7.26       11.05       10.19
# TrackerDistance                 2.66        7.26       11.05       10.19
# LoggedActivitiesDistance         0.0         0.0    2.092147    2.253081
# VeryActiveDistance               0.0        1.99        4.09         5.0
# ModeratelyActiveDistance         0.0        0.82        0.79        0.75
# LightActiveDistance             2.66        4.45        6.17        4.44
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0          25         105         113
# FairlyActiveMinutes                0          13          16          15
# LightlyActiveMinutes             144         243         220         189
# SedentaryMinutes                 657         600         658         686
# Calories                        2702        3304        4234        4128
#
#                                  418         419         420         421  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8378563200  8378563200  8378563200  8378563200
# ActivityDate                4/6/2016    4/7/2016    4/8/2016    4/9/2016
# TotalSteps                      9124        9725        8350        2240
# TotalDistance                   7.24        7.71        6.62        1.78
# TrackerDistance                 7.24        7.71        6.62        1.78
# LoggedActivitiesDistance    2.092147    2.253081    2.092147         0.0
# VeryActiveDistance               0.0        2.41        1.49         0.0
# ModeratelyActiveDistance        0.25        0.53        0.53         0.0
# LightActiveDistance             6.99        4.77        4.61        1.78
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 55          83          72           0
# FairlyActiveMinutes                6          11          10           0
# LightlyActiveMinutes             230         181         167         110
# SedentaryMinutes                 728         670         868         843
# Calories                        3798        3839        3713        2606
#
#                                  422         423         424         425  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8378563200  8378563200  8378563200  8583815059
# ActivityDate               4/10/2016   4/11/2016   4/12/2016    4/1/2016
# TotalSteps                      2631        8837        3246        2174
# TotalDistance                   2.09        7.01        2.57         1.7
# TrackerDistance                 2.09        7.01        2.57         1.7
# LoggedActivitiesDistance         0.0    2.092147    2.253081         0.0
# VeryActiveDistance               0.0        1.54        0.83         0.0
# ModeratelyActiveDistance         0.0        0.88        0.71         0.0
# LightActiveDistance             2.09        4.59        1.03         1.7
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0          74          65           0
# FairlyActiveMinutes                0          17          15           0
# LightlyActiveMinutes             117         182          49         112
# SedentaryMinutes                 727         811         243        1328
# Calories                        2624        3775        1882        2360
#
#                                  426         427         428         429  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8583815059  8583815059  8583815059  8583815059
# ActivityDate                4/2/2016    4/3/2016    4/4/2016    4/5/2016
# TotalSteps                      3494        2380        3159        6835
# TotalDistance                   2.73        1.86        2.46        5.33
# TrackerDistance                 2.73        1.86        2.46        5.33
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0        0.37
# ModeratelyActiveDistance         0.0         0.0         0.0        0.73
# LightActiveDistance             2.69        1.86        2.46        4.24
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           5
# FairlyActiveMinutes                0           0           0          15
# LightlyActiveMinutes             166         131         147         212
# SedentaryMinutes                1274        1309        1293        1208
# Calories                        2517        2400        2462        2786
#
#                                  430         431         432         433  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8583815059  8583815059  8583815059  8792009665
# ActivityDate                4/6/2016    4/7/2016    4/8/2016    4/1/2016
# TotalSteps                      2098        2816        1408        4592
# TotalDistance                   1.64         2.2         1.1        2.94
# TrackerDistance                 1.64         2.2         1.1        2.94
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         0.1
# ModeratelyActiveDistance         0.0         0.0         0.0        0.14
# LightActiveDistance             1.63         2.2         1.1         2.7
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0           4
# FairlyActiveMinutes                0           0           0           8
# LightlyActiveMinutes             112         138          79         176
# SedentaryMinutes                1328        1302        1052         748
# Calories                        2354        2437        1814        2260
#
#                                  434         435         436         437  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8792009665  8792009665  8792009665  8792009665
# ActivityDate                4/2/2016    4/3/2016    4/4/2016    4/5/2016
# TotalSteps                      8452        7238        3821        2332
# TotalDistance                   5.41        4.63        2.45        1.49
# TrackerDistance                 5.41        4.63        2.45        1.49
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance              0.26        0.11         0.0        0.01
# ModeratelyActiveDistance        0.39        0.23        0.22        0.18
# LightActiveDistance             4.76        4.29        2.23         1.3
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  9           2           0           1
# FairlyActiveMinutes               24           6           9          10
# LightlyActiveMinutes             328         279         161         111
# SedentaryMinutes                1079         636         675         904
# Calories                        3004        2667        2229        2100
#
#                                  438         439         440         441  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8792009665  8792009665  8792009665  8792009665
# ActivityDate                4/6/2016    4/7/2016    4/8/2016    4/9/2016
# TotalSteps                      2121        1291        1467        1022
# TotalDistance                   1.36        0.83        0.94        0.65
# TrackerDistance                 1.36        0.83        0.94        0.65
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.1         0.0
# ModeratelyActiveDistance         0.0         0.0        0.21         0.0
# LightActiveDistance             1.36        0.83        0.63        0.65
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           2           0
# FairlyActiveMinutes                0           0           8           0
# LightlyActiveMinutes             122          77          71          63
# SedentaryMinutes                 855         888         912         739
# Calories                        2114        1961        1953        1890
#
#                                  442         443         444         445  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8792009665  8792009665  8792009665  8877689391
# ActivityDate               4/10/2016   4/11/2016   4/12/2016    4/1/2016
# TotalSteps                      4605         178          20       18700
# TotalDistance                   2.95        0.11        0.01       15.82
# TrackerDistance                 2.95        0.11        0.01       15.82
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance               0.0         0.0         0.0         8.7
# ModeratelyActiveDistance         0.0         0.0         0.0        0.16
# LightActiveDistance             2.95        0.11        0.01        6.91
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                  0           0           0          67
# FairlyActiveMinutes                0           0           0           3
# LightlyActiveMinutes             179          12           6         247
# SedentaryMinutes                1261        1428         598        1123
# Calories                        2253        1725         728        3527
#
#                                  446         447         448         449  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8877689391  8877689391  8877689391  8877689391
# ActivityDate                4/2/2016    4/3/2016    4/4/2016    4/5/2016
# TotalSteps                     27572       15260       20779       10695
# TotalDistance              23.389999        8.19       18.41        8.12
# TrackerDistance            23.389999        8.19       18.41        8.12
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance             14.72         1.8       11.73        0.77
# ModeratelyActiveDistance        1.21        0.75        0.65        0.18
# LightActiveDistance             7.34        5.57         6.0        7.09
# SedentaryActiveDistance         0.01         0.0         0.0        0.01
# VeryActiveMinutes                116         106          78          10
# FairlyActiveMinutes               24          17          16           3
# LightlyActiveMinutes             260         259         208         246
# SedentaryMinutes                1040        1058        1138        1181
# Calories                        4220        3864        3662        2834
#
#                                  450         451         452         453  \
# _id                              NaN         NaN         NaN         NaN
# Id                        8877689391  8877689391  8877689391  8877689391
# ActivityDate                4/6/2016    4/7/2016    4/8/2016    4/9/2016
# TotalSteps                     24136       10910       23014       16470
# TotalDistance                  20.91        8.42   20.389999        8.07
# TrackerDistance                20.91        8.42   20.389999        8.07
# LoggedActivitiesDistance         0.0         0.0         0.0         0.0
# VeryActiveDistance             12.22        2.96        11.1         0.0
# ModeratelyActiveDistance        0.54        0.39        0.63        0.02
# LightActiveDistance             8.08        5.03        8.62        8.02
# SedentaryActiveDistance          0.0         0.0         0.0         0.0
# VeryActiveMinutes                 87          32          70          90
# FairlyActiveMinutes               16          11          29           9
# LightlyActiveMinutes             318         212         359         289
# SedentaryMinutes                1019        1185         982        1052
# Calories                        4039        2947        4196        3841
#
#                                  454         455         456
# _id                              NaN         NaN         NaN
# Id                        8877689391  8877689391  8877689391
# ActivityDate               4/10/2016   4/11/2016   4/12/2016
# TotalSteps                     28497       10622        2350
# TotalDistance              27.530001        8.06        1.78
# TrackerDistance            27.530001        8.06        1.78
# LoggedActivitiesDistance         0.0         0.0         0.0
# VeryActiveDistance             21.92        1.47         0.0
# ModeratelyActiveDistance        1.12        0.15         0.0
# LightActiveDistance             4.46        6.37        1.78
# SedentaryActiveDistance          0.0        0.01         0.0
# VeryActiveMinutes                128          18           0
# FairlyActiveMinutes               46           7           0
# LightlyActiveMinutes             211         225          58
# SedentaryMinutes                1055        1190         531
# Calories                        4526        2820         938

# %% [markdown]
# #### 3. Convert all the dates avaible in dataset to timestamp format in pandas and in sql convert it in date format.

# %%
# original dataset

df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %% [markdown]
# **The `ActivityDate` column in pandas is already changed to datetime format. Let's make the change in MySQL.**

# %% [markdown]
# #####  In MySQL Database datatypes before the change

# %%
# query
q = 'DESC fitbit;'

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    


# creating dtaframe of the result
df1 = pd.DataFrame(from_db)
df1
# Out:
# Query reading was successful
#                            0            1    2 3     4 5
# 0                         Id    b'bigint'  YES    None
# 1               ActivityDate  b'datetime'  YES    None
# 2                 TotalSteps    b'bigint'  YES    None
# 3              TotalDistance    b'double'  YES    None
# 4            TrackerDistance    b'double'  YES    None
# 5   LoggedActivitiesDistance    b'double'  YES    None
# 6         VeryActiveDistance    b'double'  YES    None
# 7   ModeratelyActiveDistance    b'double'  YES    None
# 8        LightActiveDistance    b'double'  YES    None
# 9    SedentaryActiveDistance    b'double'  YES    None
# 10         VeryActiveMinutes    b'bigint'  YES    None
# 11       FairlyActiveMinutes    b'bigint'  YES    None
# 12      LightlyActiveMinutes    b'bigint'  YES    None
# 13          SedentaryMinutes    b'bigint'  YES    None
# 14                  Calories    b'bigint'  YES    None

# %% [markdown]
# ##### In MySQL Database changing the type of the datetime column to date

# %%
# query
query = 'ALTER TABLE fitbit MODIFY ActivityDate DATE;'

execute_query(db_connection, query)
# Out:
# Query execution was successful

# %% [markdown]
# ##### In MySQL Database datatypes after the change

# %%
# query
q = 'DESC fitbit;'

# calling the function to get result
results = read_query(db_connection, q)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    


# creating dtaframe of the result
df1 = pd.DataFrame(from_db)
df1
# Out:
# Query reading was successful
#                            0          1    2 3     4 5
# 0                         Id  b'bigint'  YES    None
# 1               ActivityDate    b'date'  YES    None
# 2                 TotalSteps  b'bigint'  YES    None
# 3              TotalDistance  b'double'  YES    None
# 4            TrackerDistance  b'double'  YES    None
# 5   LoggedActivitiesDistance  b'double'  YES    None
# 6         VeryActiveDistance  b'double'  YES    None
# 7   ModeratelyActiveDistance  b'double'  YES    None
# 8        LightActiveDistance  b'double'  YES    None
# 9    SedentaryActiveDistance  b'double'  YES    None
# 10         VeryActiveMinutes  b'bigint'  YES    None
# 11       FairlyActiveMinutes  b'bigint'  YES    None
# 12      LightlyActiveMinutes  b'bigint'  YES    None
# 13          SedentaryMinutes  b'bigint'  YES    None
# 14                  Calories  b'bigint'  YES    None

# %% [markdown]
# #### 4. Find out number of unique IDs in the dataset.

# %%
num = len(df['Id'].unique())

print(f"Number of unique ids in the dataset are {num}")
# Out:
# Number of unique ids in the dataset are 35

# %% [markdown]
# #### 5. Which ID is one of the active id in the whole dataset.

# %%
# creating a column with total active minutes for each id

df['total_active_mins'] = df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes'] + df['SedentaryMinutes']

df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886
#
#    total_active_mins
# 0               1054
# 1                968
# 2                934
# 3               1363
# 4               1062

# %%
df_active = df.groupby('Id')['total_active_mins'].sum().sort_values(ascending = False).reset_index()

df_active
# Out:
#             Id  total_active_mins
# 0   4057192912              45051
# 1   4020332650              39210
# 2   1624580081              26613
# 3   1503960366              20705
# 4   2873212765              17079
# 5   8253242879              17065
# 6   2320127002              16526
# 7   2022484408              16504
# 8   8877689391              16429
# 9   4558609924              16107
# 10  7007744171              16069
# 11  4445114986              16020
# 12  8053475328              15015
# 13  4702921684              14905
# 14  2347167796              14585
# 15  1844505072              14344
# 16  3372868164              13873
# 17  6290855005              13474
# 18  1644430081              13202
# 19  6962181067              13009
# 20  1927972279              12795
# 21  4319703577              12643
# 22  7086361926              12408
# 23  8792009665              12391
# 24  6391747486              11718
# 25  6117666160              11686
# 26  3977333714              11509
# 27  8583815059              11211
# 28  4388161847              11074
# 29  8378563200              11026
# 30  6775888955              10899
# 31  2891001357              10809
# 32  5577150313              10264
# 33  5553957443               9976
# 34  2026352035               9942

# %%
# So the most active id is

filt = (df_active.total_active_mins == df_active.total_active_mins.max())

print("The most active id is:")
df_active.loc[filt]
# Out:
# The most active id is:
#            Id  total_active_mins
# 0  4057192912              45051

# %%
# Let's also find the Ids who was most active on any particular day

filt = (df['total_active_mins'] == df['total_active_mins'].max())

df[filt]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 5    1503960366   2016-03-30       10970       7.160000         7.160000
# 12   1503960366   2016-04-06       11974       7.670000         7.670000
# 13   1503960366   2016-04-07       10198       6.440000         6.440000
# 14   1503960366   2016-04-08       12521       7.940000         7.940000
# 19   1624580081   2016-03-25        1810       1.180000         1.180000
# ..          ...          ...         ...            ...              ...
# 451  8877689391   2016-04-07       10910       8.420000         8.420000
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 5                         0.0                2.36                      0.51
# 12                        0.0                2.04                      0.48
# 13                        0.0                1.20                      0.79
# 14                        0.0                3.31                      0.90
# 19                        0.0                0.00                      0.00
# ..                        ...                 ...                       ...
# 451                       0.0                2.96                      0.39
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 5                   4.29                     0.00                 30
# 12                  5.15                     0.00                 27
# 13                  4.45                     0.00                 17
# 14                  3.74                     0.00                 46
# 19                  1.13                     0.01                  0
# ..                   ...                      ...                ...
# 451                 5.03                     0.00                 32
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 5                     13                   223              1174      1820
# 12                    12                   228              1173      1861
# 13                    20                   195              1208      1755
# 14                    22                   212              1160      1895
# 19                     0                   121              1319      1373
# ..                   ...                   ...               ...       ...
# 451                   11                   212              1185      2947
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
#
#      total_active_mins
# 5                 1440
# 12                1440
# 13                1440
# 14                1440
# 19                1440
# ..                 ...
# 451               1440
# 452               1440
# 453               1440
# 454               1440
# 455               1440
#
# [233 rows x 16 columns]

# %% [markdown]
# #### 6. How many of them have not logged their activity? (find out in terms of number of ids)

# %%
# 1st see how many different values are there in the Logged activities

df['LoggedActivitiesDistance'].value_counts()
# Out:
# 0.000000    433
# 2.092147      4
# 2.253081      3
# 1.609344      1
# 5.189850      1
# 3.218688      1
# 4.869783      1
# 4.842320      1
# 4.875990      1
# 4.835720      1
# 4.836380      1
# 4.901283      1
# 0.055843      1
# 4.828032      1
# 5.456864      1
# 1.926302      1
# 3.972795      1
# 6.727057      1
# 2.027773      1
# 2.696455      1
# Name: LoggedActivitiesDistance, dtype: int64

# %%
unlog = df.groupby(['Id','LoggedActivitiesDistance'])['LoggedActivitiesDistance'].count().sort_values(ascending = False) 

df_unlog = pd.DataFrame(unlog)


cols = []
count = 1
for column in df_unlog.columns:
    if column == 'LoggedActivitiesDistance':
        cols.append(f'LoggedActivitiesDistance_{count}')
        count+=1
        continue
    cols.append(column)
df_unlog.columns = cols

df_unlog
# Out:
#                                      LoggedActivitiesDistance_1
# Id         LoggedActivitiesDistance
# 4020332650 0.000000                                          32
# 4057192912 0.000000                                          31
# 1503960366 0.000000                                          19
# 1624580081 0.000000                                          19
# 4702921684 0.000000                                          15
# 2347167796 0.000000                                          15
# 4445114986 0.000000                                          15
# 3977333714 0.000000                                          12
# 8792009665 0.000000                                          12
# 8253242879 0.000000                                          12
# 7086361926 0.000000                                          12
# 5553957443 0.000000                                          12
# 4558609924 0.000000                                          12
# 4319703577 0.000000                                          12
# 8877689391 0.000000                                          12
# 2022484408 0.000000                                          12
# 1844505072 0.000000                                          12
# 1927972279 0.000000                                          12
# 2873212765 0.000000                                          12
# 2320127002 0.000000                                          12
# 2026352035 0.000000                                          12
# 8053475328 0.000000                                          11
# 5577150313 0.000000                                          11
# 3372868164 0.000000                                          10
# 1644430081 0.000000                                          10
# 6962181067 0.000000                                          10
# 6290855005 0.000000                                          10
# 6117666160 0.000000                                          10
# 6775888955 0.000000                                           9
# 8583815059 0.000000                                           8
# 4388161847 0.000000                                           8
# 6391747486 0.000000                                           7
# 2891001357 0.000000                                           5
# 8378563200 0.000000                                           5
# 7007744171 0.000000                                           5
# 8378563200 2.092147                                           4
#            2.253081                                           3
# 7007744171 4.901283                                           1
# 2891001357 3.218688                                           1
# 4057192912 0.055843                                           1
# 2891001357 1.609344                                           1
# 7007744171 5.189850                                           1
#            4.842320                                           1
#            4.875990                                           1
#            4.869783                                           1
#            4.836380                                           1
#            4.835720                                           1
# 6962181067 5.456864                                           1
#            3.972795                                           1
# 2891001357 4.828032                                           1
# 6962181067 1.926302                                           1
# 6391747486 6.727057                                           1
#            2.027773                                           1
# 6962181067 2.696455                                           1

# %%
# let's check the number of Ids without log
# As from the previous data we can find that the least number of entries as 0 is 5

filt = (df_unlog.LoggedActivitiesDistance_1 > 4)

len(df_unlog.loc[filt])
# Out:
# 35

# %%
# As we can see all the Ids atleast once did not log their activity so let's find out how many total unlog ids are there

# Now find out how many has the value as 0

filt = (df['LoggedActivitiesDistance'] == 0)


num = len(df.loc[filt, 'Id'])


print(f"Number of Ids have not logged their activity is: {num}")
# Out:
# Number of Ids have not logged their activity is: 433

# %% [markdown]
# #### 7. Find out who is the laziest person ID that we have in dataset.

# %%
df_active = df.groupby('Id')['total_active_mins'].sum().sort_values().reset_index()

# So the least active id is

filt = (df_active.total_active_mins == df_active.total_active_mins.min())

print("The least active id is:")
df_active.loc[filt]
# Out:
# The least active id is:
#            Id  total_active_mins
# 0  2026352035               9942

# %%
# Let's also find the Id who was least active on any particular day

filt = (df['total_active_mins'] == df['total_active_mins'].min())

df[filt]
# Out:
#             Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 18  1503960366   2016-04-12         224           0.14             0.14
#
#     LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 18                       0.0                 0.0                       0.0
#
#     LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 18                 0.13                      0.0                  0
#
#     FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 18                    0                     9                32        50
#
#     total_active_mins
# 18                 41

# %% [markdown]
# #### 8 . Explore over internet that how much calories burn is required for a healthy person and find out how many healthy persons we have in our dataset.

# %%
# The calories needed to burn on an average per day to stay healthy is for Men= 2500Cal and Female= 2000 Cal
# As here we don't have a gender column so we will take the 2500 as our goal to stay healthy

healthy = (df['Calories'] >= 2500)

count = df.loc[healthy, 'Id'].count()

print(f"So number of healthy Ids on a day in this dataset are: {count}")
# Out:
# So number of healthy Ids on a day in this dataset are: 133

# %% [markdown]
# #### 9. How many person are not a regular person with respect to activity try to find out those.

# %%
# The starting date entered in the dataset is

df.ActivityDate.min()
# Out:
# Timestamp('2016-03-12 00:00:00')

# %%
# The last date entered in the dataset is

df.ActivityDate.max()
# Out:
# Timestamp('2016-04-12 00:00:00')

# %%
# To be considered as regular a person needed to use the app atleast 8 days (25%) as it is a 31 day dataset

start_date = df.groupby('Id')['ActivityDate'].min()   # to find each id's 1st date in the app
last_date = df.groupby('Id')['ActivityDate'].max()    # to find each id's latest date in the app

total_usage_days = last_date - start_date             # total usage days for each id

td = total_usage_days.sort_values(ascending = False)

df_td = td.reset_index()

df_td.index = df_td.index + 1

df_td.rename(columns={'ActivityDate' : 'Total_days'}, inplace=True)

df_td
# Out:
#             Id Total_days
# 1   4057192912    31 days
# 2   4020332650    31 days
# 3   1503960366    18 days
# 4   1624580081    18 days
# 5   2347167796    14 days
# 6   4702921684    14 days
# 7   4445114986    14 days
# 8   6962181067    13 days
# 9   2320127002    11 days
# 10  4558609924    11 days
# 11  8792009665    11 days
# 12  8378563200    11 days
# 13  8253242879    11 days
# 14  7086361926    11 days
# 15  7007744171    11 days
# 16  2026352035    11 days
# 17  5553957443    11 days
# 18  8877689391    11 days
# 19  1844505072    11 days
# 20  2022484408    11 days
# 21  2873212765    11 days
# 22  3977333714    11 days
# 23  1927972279    11 days
# 24  4319703577    11 days
# 25  8053475328    10 days
# 26  5577150313    10 days
# 27  6290855005     9 days
# 28  1644430081     9 days
# 29  6117666160     9 days
# 30  3372868164     9 days
# 31  6391747486     8 days
# 32  6775888955     8 days
# 33  2891001357     7 days
# 34  8583815059     7 days
# 35  4388161847     7 days

# %%
# Let's see the data types
df_td.dtypes
# Out:
# Id                      int64
# Total_days    timedelta64[ns]
# dtype: object

# %%
# changing the datatype to int

df_td['Total_days'] = df_td['Total_days'].dt.days.astype('int64')

# %%
# Let's see again the data types
df_td.dtypes
# Out:
# Id            int64
# Total_days    int64
# dtype: object

# %%
# Let's find the ids who have used the app less than 8 days

filt = (df_td['Total_days'] < 8)

print("So the irregular ids are:")
df_td.loc[filt, 'Id']
# Out:
# So the irregular ids are:
# 33    2891001357
# 34    8583815059
# 35    4388161847
# Name: Id, dtype: int64

# %% [markdown]
# #### 10. Who is the third most active person in this dataset find out those in pandas and in sql both.

# %%
# sorting the dataset on the basis of total active mins used by each id in descending order

df_third = df.groupby('total_active_mins').max().sort_values(by='total_active_mins', ascending=False).reset_index()

df_third.index = df_third.index + 1

df_third.head(3)
# Out:
#    total_active_mins          Id ActivityDate  TotalSteps  TotalDistance  \
# 1               1440  8877689391   2016-04-12       28497      27.530001
# 2               1427  6775888955   2016-04-01        7225       5.180000
# 3               1419  2347167796   2016-04-09       16081      10.630000
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 1        27.530001                  6.727057               21.92
# 2         5.180000                  0.000000                1.73
# 3        10.630000                  0.000000                1.25
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 1                      6.40                12.00                     0.06
# 2                      1.27                 2.18                     0.00
# 3                      1.82                 7.56                     0.00
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 1                165                  660                   720
# 2                 25                   50                   163
# 3                 16                   32                   401
#
#    SedentaryMinutes  Calories
# 1              1440      4562
# 2              1189      3065
# 3               970      2488

# %%
print(f"So the third most active person in the dataset is: {df_third.loc[3, 'Id']}")
# Out:
# So the third most active person in the dataset is: 2347167796

# %% [markdown]
# #### 11. Who is the 5th most laziest person avilable in dataset find it out.

# %%
# sorting the dataset on the basis of total active mins used by each id in ascending order

df_fifth = df.groupby('total_active_mins').max().sort_values(by='total_active_mins').reset_index()

df_fifth.index = df_fifth.index + 1

df_fifth.head(5)
# Out:
#    total_active_mins          Id ActivityDate  TotalSteps  TotalDistance  \
# 1                 41  1503960366   2016-04-12         224           0.14
# 2                 89  7086361926   2016-04-12         430           0.26
# 3                129  5553957443   2016-04-12        3436           2.24
# 4                164  1927972279   2016-04-12          24           0.02
# 5                198  6391747486   2016-04-09           0           0.00
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 1             0.14                       0.0                 0.0
# 2             0.26                       0.0                 0.0
# 3             2.24                       0.0                 0.5
# 4             0.02                       0.0                 0.0
# 5             0.00                       0.0                 0.0
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 1                      0.00                 0.13                      0.0
# 2                      0.00                 0.26                      0.0
# 3                      0.67                 1.05                      0.0
# 4                      0.00                 0.02                      0.0
# 5                      0.00                 0.00                      0.0
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 1                  0                    0                     9
# 2                  0                    0                    14
# 3                  7                   11                    50
# 4                  0                    0                     3
# 5                  0                    0                     0
#
#    SedentaryMinutes  Calories
# 1                32        50
# 2                75       625
# 3                61       633
# 4               161       942
# 5               198       251

# %%
print(f"So the fifth most laziest person in the dataset is: {df_fifth.loc[5, 'Id']}")
# Out:
# So the fifth most laziest person in the dataset is: 6391747486

# %% [markdown]
# #### 12. What is a total acumulative calories burn for a person find out.

# %%
df_ac = df.groupby('Id')['Calories'].sum().sort_values(ascending=False).reset_index()

df_td = td

df_ac.index = df_ac.index + 1

df_ac.rename(columns={'Calories' : 'Accumulative calories'}, inplace=True)

df_ac
# Out:
#             Id  Accumulative calories
# 1   4020332650                  98412
# 2   4057192912                  60913
# 3   4702921684                  42322
# 4   8877689391                  41414
# 5   8378563200                  40274
# 6   5577150313                  36303
# 7   1503960366                  34128
# 8   8053475328                  31825
# 9   4445114986                  31617
# 10  7007744171                  31525
# 11  2347167796                  30320
# 12  2022484408                  29704
# 13  6962181067                  29249
# 14  1644430081                  29164
# 15  1927972279                  27048
# 16  7086361926                  26124
# 17  1624580081                  25705
# 18  8792009665                  24884
# 19  6775888955                  24523
# 20  4319703577                  23931
# 21  4558609924                  21962
# 22  6290855005                  21656
# 23  5553957443                  21630
# 24  6117666160                  20993
# 25  2873212765                  20349
# 26  1844505072                  19391
# 27  8583815059                  19130
# 28  3372868164                  18603
# 29  2320127002                  18385
# 30  2891001357                  18187
# 31  8253242879                  17556
# 32  3977333714                  16777
# 33  2026352035                  16266
# 34  6391747486                  15868
# 35  4388161847                  14442

# %% [markdown]
# ## Task 2 - Superstore_USA dataset:

# %%
# import the libraries

import pandas as pd
import mysql.connector as conn
from mysql.connector import Error
from sqlalchemy import create_engine

# %% [markdown]
# #### 1. Load this data in sql and in pandas with a relation in sql.(Create Primary key, Foreign key)
#
# #### 2. While loading this data you don't have to create a table manually you can use any automated approach to create a table and load a data in bulk in table.

# %% [markdown]
# ##### Loading datasets in pandas:

# %%
# creating dataframe of 1st sheet

df_order = pd.read_excel('dataset/Superstore_USA.xlsx','Orders')
pd.set_option('display.max_columns', None)

df_order.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID
# 0    1.3200                     2     5.90     88525
# 1    4.5600                     4    13.01     88522
# 2  -47.6400                     7    49.92     88523
# 3  -30.5100                     7    41.64     88523
# 4  998.2023                     8  1446.67     88523

# %%
# creating dataframe of 2nd sheet

df_return = pd.read_excel('dataset/Superstore_USA.xlsx','Returns')

df_return.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
# creating dataframe of 3rd sheet

df_users = pd.read_excel('dataset/Superstore_USA.xlsx','Users')

df_users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ##### Loading datasets in MySQL:

# %%
# Creating functions for MySQL

# Server connection
def create_server_connection(host_name, user_name, user_pwd):
    connection = None
    try:
        connection = conn.connect(host=host_name, user=user_name, passwd=user_pwd)

        print("Connection to MySQL is successful.")

    except Error as err:
        print(f"Error is: {err}")

    else:
        return connection
    

    
# Creating database
def create_database(connection, query):
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        print("Database created successfully")

    except Error as err:
        print(f"Error is: {err}")
        

        
# Connecting to the database
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = conn.connect(host=host_name, user=user_name, passwd=user_password, database=db_name)
        print("Connected to the Database Successfully")

    except Error as err:
        print(f"Error is: {err}")

    else:
        return connection
 


    
# Executing query
def execute_query(connection, query):
    cursor = connection.cursor()

    try:
        cursor.execute(query)
        connection.commit()
        print("Query execution was successful")

    except Error as err:
        print(f"Error is: {err}")
        

        
        
# Showing query results
def read_query(connection, query):
    cursor = connection.cursor()
    result = None

    try:
        cursor.execute(query)
        result = cursor.fetchall()
        print("Query reading was successful")

    except Error as err:
        print(f"Error: {err}")

    else:
        return result

# %%
# Connection with MySQL

host = "localhost"
user = "root"
pw = "Password"

connection = create_server_connection(host, user, pw)
# Out:
# Connection to MySQL is successful.

# %%
# Creating the database

query = "CREATE DATABASE IF NOT EXISTS panda_exercise"
create_database(connection, query)
# Out:
# Database created successfully

# %%
# Connecting with the database

db = "panda_exercise"

db_connection = create_db_connection(host, user, pw, db)
# Out:
# Connected to the Database Successfully

# %%
# Creating table and inserting data from the 1st dataframe

engine = create_engine("mysql+pymysql://root:Password@localhost:3306/panda_exercise")


try:
    df_order.to_sql(name='orders', con=engine, index=False, if_exists='replace')
except Exception as e:
    print("Error is: ", e)
else:
    print("Query is Successful")
# Out:
# Query is Successful

# %%
# Creating table and inserting data from the 2nd dataframe

engine = create_engine("mysql+pymysql://root:Password@localhost:3306/panda_exercise")


try:
    df_return.to_sql(name='returns', con=engine, index=False, if_exists='replace')
except Exception as e:
    print("Error is: ", e)
else:
    print("Query is Successful")
# Out:
# Query is Successful

# %%
# Creating table and inserting data from the 3rd dataframe

engine = create_engine("mysql+pymysql://root:Password@localhost:3306/panda_exercise")


try:
    df_users.to_sql(name='users', con=engine, index=False, if_exists='replace')
except Exception as e:
    print("Error is: ", e)
else:
    print("Query is Successful")
# Out:
# Query is Successful

# %%
# Now creating the primary key for returns table

query = "ALTER TABLE `returns` ADD PRIMARY KEY(`Order ID`);"
execute_query(db_connection, query)
# Out:
# Query execution was successful

# %%
# Now creating the primary key for users table

query = "ALTER TABLE users ADD PRIMARY KEY(Region);"
execute_query(db_connection, query)
# Out:
# Query execution was successful

# %%
# Now creating the foreign keys for orders table with reference to users table

query = "ALTER TABLE orders ADD FOREIGN KEY(Region) REFERENCES users(Region);"
execute_query(db_connection, query)
# Out:
# Query execution was successful

# %%
# Now creating the foreign keys for orders table with reference to returns table

query = "ALTER TABLE orders ADD FOREIGN KEY(`Order ID`) REFERENCES `returns`(`Order ID`);"
execute_query(db_connection, query)
# Out:
# Error is: 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`panda_exercise`.`#sql-11f4_11d`, CONSTRAINT `orders_ibfk_2` FOREIGN KEY (`Order ID`) REFERENCES `returns` (`Order ID`))

# %% [markdown]
# - As we can see ERROR 1452 (23000) is generated because some current values in child column Order ID of the referencing table orders are not in the parent column Order ID of the referenced table returns.
#
# - `select * from orders where Order ID not in (select distinct Order ID from returns);`
#
# - Using the above subquery we can retrieve all the legal parent values of Order ID from the referenced table returns as the filter, and select all the child values of Order ID that are not in the legal parent values from the referencing table orders. Then we can delete them or update them in order to comply with the coming constraint.
#
# - But this will disturb the dataset so did not take the route. Also it is not mandatory to create Primary and Foreign key to perform Join on tables.
#
# - Because a primary key enforces the consistency of uniqueness of values over one or more columns. If an ID column has a primary key then it is impossible to have two rows with the same ID value. And a foreign key enforces the consistency of data that points elsewhere. It ensures that the data which is pointed to actually exists. In a typical parent-child relationship, a foreign key ensures that every child always points at a parent and that the parent actually exists.

# %% [markdown]
# #### 3. Find out how many return that we have recived and with a product id.

# %%
num = len(pd.merge(df_order, df_return, left_on='Order ID', right_on='Order ID', how='inner'))

print(f"The number of items returned with product id received is: {num}")
# Out:
# The number of items returned with product id received is: 98

# %% [markdown]
# #### 4. Try to join order and return data both in sql and pandas.

# %% [markdown]
# ##### In MySQL:

# %%
# query
query = "SELECT o.*, r.status FROM orders o join `returns` r on o.`Order ID` = r.`Order ID`;"

# calling the function to get result
results = read_query(db_connection, query)

# collecting the result from the database
from_db = []

for result in results:
    result = list(result)
    from_db.append(result)
    
# creating column names
cols = ['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',\
       'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',\
       'Product Category', 'Product Sub-Category', 'Product Container',\
       'Product Name', 'Product Base Margin', 'Region', 'State or Province',\
       'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',\
       'Quantity ordered new', 'Sales', 'Order ID', 'Status']

# creating dataframe of the result
df1 = pd.DataFrame(from_db, columns = cols)
display(df1)
# Out:
# Query reading was successful
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
#            Customer Name    Ship Mode Customer Segment Product Category  \
# 0   Tony Wilkins Winters  Regular Air   Small Business  Office Supplies
# 1            Linda Weiss  Regular Air      Home Office  Office Supplies
# 2            Linda Weiss  Express Air      Home Office  Office Supplies
# 3            Linda Weiss  Regular Air      Home Office  Office Supplies
# 4          Eleanor Swain  Regular Air   Small Business  Office Supplies
# ..                   ...          ...              ...              ...
# 93         Gordon Brandt  Regular Air        Corporate  Office Supplies
# 94         Gordon Brandt  Regular Air        Corporate  Office Supplies
# 95         Gordon Brandt  Express Air        Corporate  Office Supplies
# 96         Andrew Levine  Regular Air         Consumer       Technology
# 97          Peter Brooks  Regular Air   Small Business        Furniture
#
#       Product Sub-Category Product Container  \
# 0      Pens & Art Supplies          Wrap Bag
# 1                   Labels         Small Box
# 2                    Paper          Wrap Bag
# 3      Pens & Art Supplies          Wrap Bag
# 4      Pens & Art Supplies        Small Pack
# ..                     ...               ...
# 93                   Paper          Wrap Bag
# 94  Storage & Organization         Small Box
# 95                   Paper         Small Box
# 96    Computer Peripherals        Small Pack
# 97      Chairs & Chairmats        Medium Box
#
#                                          Product Name  Product Base Margin  \
# 0               Dixon My First Ticonderoga Pencil, #2                 0.56
# 1                                           Avery 493                 0.36
# 2                               EcoTones® Memo Sheets                 0.37
# 3                                           Newell 35                 0.56
# 4                   Staples SlimLine Pencil Sharpener                 0.60
# ..                                                ...                  ...
# 93  Snap-A-Way® Black Print Carbonless Ruled Speed...                 0.38
# 94  Recycled Steel Personal File for Standard File...                 0.59
# 95                                         Xerox 1980                 0.40
# 96                                   TDK 4.7GB DVD+RW                 0.49
# 97                        SAFCO Folding Chair Trolley                  NaN
#
#    Region State or Province           City  Postal Code Order Date  Ship Date  \
# 0    East          New York  New York City        10012 2011-04-20 2011-04-24
# 1    West        Washington        Seattle        98103 2010-04-04 2010-04-06
# 2    West        Washington        Seattle        98103 2010-04-04 2010-04-06
# 3    West        Washington        Seattle        98103 2013-08-16 2013-08-18
# 4   South    North Carolina      Charlotte        28204 2013-08-12 2013-08-12
# ..    ...               ...            ...          ...        ...        ...
# 93   West        California    Los Angeles        90061 2013-01-04 2013-01-06
# 94   West        California    Los Angeles        90061 2013-01-04 2013-01-05
# 95   West        California    Los Angeles        90061 2013-06-25 2013-06-27
# 96   East      Pennsylvania   Philadelphia        19112 2012-09-30 2012-10-02
# 97   East          New York  New York City        10112 2012-09-11 2012-09-13
#
#        Profit  Quantity ordered new     Sales  Order ID    Status
# 0     -6.8200                     9     54.79      9895  Returned
# 1    112.0600                    47    228.46     13959  Returned
# 2     16.7900                    19     77.61     13959  Returned
# 3    -89.0600                    52    190.52     36038  Returned
# 4    -81.9413                    76    912.06     39490  Returned
# ..        ...                   ...       ...       ...       ...
# 93   -33.9680                     3    113.14      7107  Returned
# 94   163.1200                    35   1886.52      7107  Returned
# 95   -22.5600                    12     73.71     42823  Returned
# 96   165.2000                    96   1337.67     13638  Returned
# 97  1844.9600                    92  12002.16     47109  Returned
#
# [98 rows x 25 columns]

# %% [markdown]
# ##### In Pandas:

# %%
pd.merge(df_order, df_return, on=['Order ID'])
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
#            Customer Name    Ship Mode Customer Segment Product Category  \
# 0   Tony Wilkins Winters  Regular Air   Small Business  Office Supplies
# 1            Linda Weiss  Regular Air      Home Office  Office Supplies
# 2            Linda Weiss  Express Air      Home Office  Office Supplies
# 3            Linda Weiss  Regular Air      Home Office  Office Supplies
# 4          Eleanor Swain  Regular Air   Small Business  Office Supplies
# ..                   ...          ...              ...              ...
# 93         Gordon Brandt  Regular Air        Corporate  Office Supplies
# 94         Gordon Brandt  Regular Air        Corporate  Office Supplies
# 95         Gordon Brandt  Express Air        Corporate  Office Supplies
# 96         Andrew Levine  Regular Air         Consumer       Technology
# 97          Peter Brooks  Regular Air   Small Business        Furniture
#
#       Product Sub-Category Product Container  \
# 0      Pens & Art Supplies          Wrap Bag
# 1                   Labels         Small Box
# 2                    Paper          Wrap Bag
# 3      Pens & Art Supplies          Wrap Bag
# 4      Pens & Art Supplies        Small Pack
# ..                     ...               ...
# 93                   Paper          Wrap Bag
# 94  Storage & Organization         Small Box
# 95                   Paper         Small Box
# 96    Computer Peripherals        Small Pack
# 97      Chairs & Chairmats        Medium Box
#
#                                          Product Name  Product Base Margin  \
# 0               Dixon My First Ticonderoga Pencil, #2                 0.56
# 1                                           Avery 493                 0.36
# 2                               EcoTones® Memo Sheets                 0.37
# 3                                           Newell 35                 0.56
# 4                   Staples SlimLine Pencil Sharpener                 0.60
# ..                                                ...                  ...
# 93  Snap-A-Way® Black Print Carbonless Ruled Speed...                 0.38
# 94  Recycled Steel Personal File for Standard File...                 0.59
# 95                                         Xerox 1980                 0.40
# 96                                   TDK 4.7GB DVD+RW                 0.49
# 97                        SAFCO Folding Chair Trolley                  NaN
#
#    Region State or Province           City  Postal Code Order Date  Ship Date  \
# 0    East          New York  New York City        10012 2011-04-20 2011-04-24
# 1    West        Washington        Seattle        98103 2010-04-04 2010-04-06
# 2    West        Washington        Seattle        98103 2010-04-04 2010-04-06
# 3    West        Washington        Seattle        98103 2013-08-16 2013-08-18
# 4   South    North Carolina      Charlotte        28204 2013-08-12 2013-08-12
# ..    ...               ...            ...          ...        ...        ...
# 93   West        California    Los Angeles        90061 2013-01-04 2013-01-06
# 94   West        California    Los Angeles        90061 2013-01-04 2013-01-05
# 95   West        California    Los Angeles        90061 2013-06-25 2013-06-27
# 96   East      Pennsylvania   Philadelphia        19112 2012-09-30 2012-10-02
# 97   East          New York  New York City        10112 2012-09-11 2012-09-13
#
#        Profit  Quantity ordered new     Sales  Order ID    Status
# 0     -6.8200                     9     54.79      9895  Returned
# 1    112.0600                    47    228.46     13959  Returned
# 2     16.7900                    19     77.61     13959  Returned
# 3    -89.0600                    52    190.52     36038  Returned
# 4    -81.9413                    76    912.06     39490  Returned
# ..        ...                   ...       ...       ...       ...
# 93   -33.9680                     3    113.14      7107  Returned
# 94   163.1200                    35   1886.52      7107  Returned
# 95   -22.5600                    12     73.71     42823  Returned
# 96   165.2000                    96   1337.67     13638  Returned
# 97  1844.9600                    92  12002.16     47109  Returned
#
# [98 rows x 25 columns]

# %% [markdown]
# #### 5. Try to find out how many unique customers that we have.

# %%
num = len(df_order['Customer Name'].unique())

print(f"The number of unique customers are: {num}")
# Out:
# The number of unique customers are: 2703

# %% [markdown]
# #### 6. Try to find out in how many regions we are selling a product and who is a manager for each respective regions.

# %%
# 1st merge the data from 2 tables

df = pd.merge(df_order, df_users, left_on='Region', right_on='Region', how='inner')

df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   24844         Medium      0.09       78.69          19.99           14
# 2   24846         Medium      0.08        3.28           2.31           14
# 3   24847         Medium      0.05        3.28           4.20           14
# 4   24848         Medium      0.05        3.58           1.63           14
#
#        Customer Name    Ship Mode Customer Segment Product Category  \
# 0    Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1  Gwendolyn F Tyson  Regular Air   Small Business        Furniture
# 2  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 3  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 4  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
#
#   Product Sub-Category Product Container  \
# 0               Labels         Small Box
# 1   Office Furnishings         Small Box
# 2  Pens & Art Supplies          Wrap Bag
# 3  Pens & Art Supplies          Wrap Bag
# 4         Rubber Bands          Wrap Bag
#
#                                         Product Name  Product Base Margin  \
# 0                                           Avery 49                 0.36
# 1  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
# 2                                         Newell 321                 0.56
# 3                                         Newell 351                 0.56
# 4           OIC Colored Binder Clips, Assorted Sizes                 0.36
#
#     Region State or Province        City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois     Addison        60101 2012-05-28 2012-05-30
# 1  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-14
# 2  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 3  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 4  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
#
#      Profit  Quantity ordered new    Sales  Order ID Manager
# 0    1.3200                     2     5.90     88525   Chris
# 1  803.4705                    16  1164.45     86838   Chris
# 2  -24.0300                     7    22.23     86838   Chris
# 3  -37.0300                     4    13.99     86838   Chris
# 4   -0.7100                     4    14.26     86838   Chris

# %%
# Total number of products per region

df.groupby(['Region'])['Product Category'].count()
# Out:
# Region
# Central    2899
# East       2289
# South      1954
# West       2284
# Name: Product Category, dtype: int64

# %%
# Number of products productwise and region wise

df.groupby(['Product Category', 'Region'])['Region'].count()
# Out:
# Product Category  Region
# Furniture         Central     623
#                   East        479
#                   South       370
#                   West        461
# Office Supplies   Central    1559
#                   East       1272
#                   South      1099
#                   West       1251
# Technology        Central     717
#                   East        538
#                   South       485
#                   West        572
# Name: Region, dtype: int64

# %%
# Respective managers along with region and products and their numbers

df.groupby(['Manager', 'Region', 'Product Category'])['Region'].count()
# Out:
# Manager  Region   Product Category
# Chris    Central  Furniture            623
#                   Office Supplies     1559
#                   Technology           717
# Erin     East     Furniture            479
#                   Office Supplies     1272
#                   Technology           538
# Sam      South    Furniture            370
#                   Office Supplies     1099
#                   Technology           485
# William  West     Furniture            461
#                   Office Supplies     1251
#                   Technology           572
# Name: Region, dtype: int64

# %% [markdown]
# #### 7. Find out how many different shipement modes that we have and what is a percentage usablity of all the shipment mode with respect to the dataset.

# %%
# checking how many modes are there

df_order['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
# counting rows of each mode

df_order['Ship Mode'].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
# total number of rows in dataset

len(df_order)
# Out:
# 9426

# %%
# creating function to calculate percentage
def percentage(op_mode):
    total = len(df_order)
    per = (op_mode / total) * 100
    return per


# creating filter for each mode
Reg_air = (df_order['Ship Mode'] == 'Regular Air')
Del_trk = (df_order['Ship Mode'] == 'Delivery Truck')
Exp_air = (df_order['Ship Mode'] == 'Express Air')

# Number of rows for each mode
reg_air = len(df_order.loc[Reg_air])
del_trk = len(df_order.loc[Del_trk])
exp_air = len(df_order.loc[Exp_air])


print(f"Percentage usability of Regular Air mode is: {percentage(reg_air):.2f}%")
print(f"Percentage usability of Delivery Truck mode is: {percentage(del_trk):.2f}%")
print(f"Percentage usability of Express Air mode is: {percentage(exp_air):.2f}%")
# Out:
# Percentage usability of Regular Air mode is: 74.64%
# Percentage usability of Delivery Truck mode is: 13.61%
# Percentage usability of Express Air mode is: 11.74%

# %% [markdown]
# #### 8. Create a new coulmn and try to find out a diffrence between order date and shipment date.

# %%
# creating new column

df_order['Date_diff'] = df_order['Ship Date'] - df_order['Order Date']

df_order.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID Date_diff
# 0    1.3200                     2     5.90     88525    2 days
# 1    4.5600                     4    13.01     88522    1 days
# 2  -47.6400                     7    49.92     88523    1 days
# 3  -30.5100                     7    41.64     88523    1 days
# 4  998.2023                     8  1446.67     88523    0 days

# %% [markdown]
# #### 9. Based on question number 8 find out for which order id we have shipment duration more than 10 days.

# %%
# 1st changing the datatype to int

df_order['Date_diff'] = df_order['Date_diff'].dt.days.astype('int64')

# %%
# Now creating the filter and checking the dataset

filt = df_order['Date_diff'] > 10

df_order.loc[filt]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# 8610   26352         Medium      0.06        4.20           2.26         3119
# 8973   20750            Low      0.06      125.99           8.08         3248
# 8982    2748            Low      0.03       11.97           5.81         3251
# 8983    2749            Low      0.08      195.99           4.20         3251
# 8993    2750            Low      0.06      125.99           8.08         3251
# 8996   20748            Low      0.03       11.97           5.81         3252
# 8997   20749            Low      0.08      195.99           4.20         3252
#
#                 Customer Name       Ship Mode Customer Segment  \
# 643   Brenda Nelson Blanchard     Regular Air        Corporate
# 1548               Dana Desai     Regular Air   Small Business
# 1549               Dana Desai     Express Air   Small Business
# 1678       Christopher Bryant  Delivery Truck         Consumer
# 1679       Christopher Bryant     Regular Air         Consumer
# 1680       Christopher Bryant     Regular Air         Consumer
# 1697               Neal Wolfe  Delivery Truck         Consumer
# 1698               Neal Wolfe     Regular Air         Consumer
# 1699               Neal Wolfe     Regular Air         Consumer
# 2515          Virginia Rivera     Regular Air      Home Office
# 5548          Ricky Dougherty     Regular Air         Consumer
# 5673             Carrie Boyle     Regular Air        Corporate
# 5859            Lester Sawyer     Regular Air      Home Office
# 5881               Anna Glenn     Regular Air      Home Office
# 8607              Jay Hubbard     Express Air        Corporate
# 8609              Jay Hubbard  Delivery Truck        Corporate
# 8610              Jay Hubbard     Regular Air        Corporate
# 8973            Earl Donnelly     Express Air        Corporate
# 8982             Peter Brooks     Regular Air        Corporate
# 8983             Peter Brooks     Regular Air        Corporate
# 8993             Peter Brooks     Express Air        Corporate
# 8996           Milton Harrell     Regular Air        Corporate
# 8997           Milton Harrell     Regular Air        Corporate
#
#      Product Category          Product Sub-Category Product Container  \
# 643   Office Supplies                     Envelopes         Small Box
# 1548       Technology          Computer Peripherals         Small Box
# 1549  Office Supplies                         Paper         Small Box
# 1678        Furniture            Chairs & Chairmats        Jumbo Drum
# 1679  Office Supplies                         Paper         Small Box
# 1680       Technology  Telephones and Communication         Small Box
# 1697        Furniture            Chairs & Chairmats        Jumbo Drum
# 1698  Office Supplies                         Paper         Small Box
# 1699       Technology  Telephones and Communication         Small Box
# 2515  Office Supplies           Pens & Art Supplies          Wrap Bag
# 5548  Office Supplies           Pens & Art Supplies          Wrap Bag
# 5673       Technology  Telephones and Communication         Small Box
# 5859       Technology          Computer Peripherals        Small Pack
# 5881       Technology  Telephones and Communication        Medium Box
# 8607       Technology          Computer Peripherals        Small Pack
# 8609  Office Supplies                    Appliances        Jumbo Drum
# 8610  Office Supplies                         Paper          Wrap Bag
# 8973       Technology  Telephones and Communication         Small Box
# 8982  Office Supplies           Pens & Art Supplies        Small Pack
# 8983       Technology  Telephones and Communication         Small Box
# 8993       Technology  Telephones and Communication         Small Box
# 8996  Office Supplies           Pens & Art Supplies        Small Pack
# 8997       Technology  Telephones and Communication         Small Box
#
#                                            Product Name  Product Base Margin  \
# 643                       #10 Self-Seal White Envelopes                 0.36
# 1548                        Logitech Cordless Elite Duo                 0.40
# 1549                                          Xerox 220                 0.37
# 1678  Office Star - Contemporary Task Swivel chair w...                 0.78
# 1679                                         Xerox 1908                 0.36
# 1680                                                282                 0.56
# 1697  Office Star - Contemporary Task Swivel chair w...                 0.78
# 1698                                         Xerox 1908                 0.36
# 1699                                                282                 0.56
# 2515                Quartet Alpha® White Chalk, 12/Pack                 0.38
# 5548       DIXON Ticonderoga® Erasable Checking Pencils                 0.46
# 5673                                               6000                 0.55
# 5859    Verbatim DVD-RAM, 5.2GB, Rewritable, Type 1, DS                 0.50
# 5881                       Bell Sonecor JB700 Caller ID                 0.60
# 8607        Imation 3.5 IBM Formatted Diskettes, 10/Box                 0.74
# 8609                    Avanti 4.4 Cu. Ft. Refrigerator                 0.57
# 8610  Important Message Pads, 50 4-1/4 x 5-1/2 Forms...                 0.36
# 8973                                              M3682                 0.57
# 8982                  Staples SlimLine Pencil Sharpener                 0.60
# 8983                                                688                 0.60
# 8993                                              M3682                 0.57
# 8996                  Staples SlimLine Pencil Sharpener                 0.60
# 8997                                                688                 0.60
#
#        Region State or Province           City  Postal Code Order Date  \
# 643   Central         Minnesota      Richfield        55423 2011-12-29
# 1548  Central           Indiana    Bloomington        47401 2011-12-30
# 1549  Central           Indiana    Bloomington        47401 2011-12-30
# 1678     West        California    Santa Clara        95051 2011-12-30
# 1679     West        California    Santa Clara        95051 2011-12-30
# 1680     West        California    Santa Clara        95051 2011-12-30
# 1697     West        Washington        Seattle        98119 2011-12-30
# 1698     West        Washington        Seattle        98119 2011-12-30
# 1699     West        Washington        Seattle        98119 2011-12-30
# 2515     West        California   Redwood City        94061 2011-12-30
# 5548  Central      South Dakota      Brookings        57006 2011-12-30
# 5673     East          New York   Mount Vernon        10550 2011-12-28
# 5859    South          Virginia        Fairfax        20151 2011-12-26
# 5881     West        California       Pasadena        91104 2011-12-26
# 8607    South           Florida        Orlando        32839 2011-12-29
# 8609    South           Florida        Orlando        32839 2013-12-29
# 8610    South           Florida        Orlando        32839 2013-12-29
# 8973    South         Louisiana        Slidell        70458 2011-12-26
# 8982     East          New York  New York City        10112 2011-12-26
# 8983     East          New York  New York City        10112 2011-12-26
# 8993     East          New York  New York City        10112 2013-12-26
# 8996     East          New York      Rotterdam        12306 2011-12-26
# 8997     East          New York      Rotterdam        12306 2011-12-26
#
#       Ship Date     Profit  Quantity ordered new     Sales  Order ID  \
# 643  2012-03-22    58.5000                    19    204.67     87215
# 1548 2012-01-10   375.7050                     6    587.46     86318
# 1549 2012-01-14   -47.3950                    12     79.37     86318
# 1678 2012-01-16  -211.8850                    21   2699.94     87957
# 1679 2012-01-10   355.0119                    10    514.51     87957
# 1680 2012-01-27  1021.4001                    16   1480.29     87957
# 1697 2012-01-16  -423.7700                    83  10671.20     19556
# 1698 2012-01-10   469.6900                    41   2109.51     19556
# 1699 2012-01-27   727.3620                    65   6013.69     19556
# 2515 2012-03-31     5.8200                    10     22.35     86177
# 5548 2012-01-13    66.2250                    21    121.51     88223
# 5673 2012-01-14   187.4880                     8    451.34     88352
# 5859 2012-01-17  4230.2001                    12    344.16     87572
# 5881 2012-01-19   -23.4520                     2     15.56     91294
# 8607 2012-01-16 -1075.3960                    19    170.62     86434
# 8609 2014-01-15  -147.5180                    25   4529.95     86436
# 8610 2014-01-17  -689.8738                     2      9.64     86436
# 8973 2012-01-14     2.4780                    20   2180.31     87300
# 8982 2012-01-22   -31.7400                    31    388.52     19841
# 8983 2012-01-26  -557.9530                    13   2092.05     19841
# 8993 2014-01-14  1304.5590                    86   9375.35     19841
# 8996 2012-01-22   -15.8700                     8    100.26     87300
# 8997 2012-01-26  -278.9765                     3    482.78     87300
#
#       Date_diff
# 643          84
# 1548         11
# 1549         15
# 1678         17
# 1679         11
# 1680         28
# 1697         17
# 1698         11
# 1699         28
# 2515         92
# 5548         14
# 5673         17
# 5859         22
# 5881         24
# 8607         18
# 8609         17
# 8610         19
# 8973         19
# 8982         27
# 8983         31
# 8993         19
# 8996         27
# 8997         31

# %% [markdown]
# #### 10. Try to find out a list of returned order where sihpment duration was more than 15 days and find out that region manager as well.

# %%
# creating dataframe merging the order and return dataset

df1 = pd.merge(df_order, df_return, on=['Order ID'])

df1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    1359            Low      0.05        5.85           2.27           21
# 1    1950         Medium      0.01        4.91           0.50          117
# 2    1951         Medium      0.09        4.00           1.30          117
# 3    5055           High      0.02        3.28           5.00          117
# 4    5573            Low      0.02       11.97           5.81          272
#
#           Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies
# 1           Linda Weiss  Regular Air      Home Office  Office Supplies
# 2           Linda Weiss  Express Air      Home Office  Office Supplies
# 3           Linda Weiss  Regular Air      Home Office  Office Supplies
# 4         Eleanor Swain  Regular Air   Small Business  Office Supplies
#
#   Product Sub-Category Product Container  \
# 0  Pens & Art Supplies          Wrap Bag
# 1               Labels         Small Box
# 2                Paper          Wrap Bag
# 3  Pens & Art Supplies          Wrap Bag
# 4  Pens & Art Supplies        Small Pack
#
#                             Product Name  Product Base Margin Region  \
# 0  Dixon My First Ticonderoga Pencil, #2                 0.56   East
# 1                              Avery 493                 0.36   West
# 2                  EcoTones® Memo Sheets                 0.37   West
# 3                              Newell 35                 0.56   West
# 4      Staples SlimLine Pencil Sharpener                 0.60  South
#
#   State or Province           City  Postal Code Order Date  Ship Date  \
# 0          New York  New York City        10012 2011-04-20 2011-04-24
# 1        Washington        Seattle        98103 2010-04-04 2010-04-06
# 2        Washington        Seattle        98103 2010-04-04 2010-04-06
# 3        Washington        Seattle        98103 2013-08-16 2013-08-18
# 4    North Carolina      Charlotte        28204 2013-08-12 2013-08-12
#
#      Profit  Quantity ordered new   Sales  Order ID  Date_diff    Status
# 0   -6.8200                     9   54.79      9895          4  Returned
# 1  112.0600                    47  228.46     13959          2  Returned
# 2   16.7900                    19   77.61     13959          2  Returned
# 3  -89.0600                    52  190.52     36038          2  Returned
# 4  -81.9413                    76  912.06     39490          0  Returned

# %%
# creating dataframe merging the order and users dataset

df2 = pd.merge(df_order, df_users, on=['Region'])

df2.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   24844         Medium      0.09       78.69          19.99           14
# 2   24846         Medium      0.08        3.28           2.31           14
# 3   24847         Medium      0.05        3.28           4.20           14
# 4   24848         Medium      0.05        3.58           1.63           14
#
#        Customer Name    Ship Mode Customer Segment Product Category  \
# 0    Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1  Gwendolyn F Tyson  Regular Air   Small Business        Furniture
# 2  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 3  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
# 4  Gwendolyn F Tyson  Regular Air   Small Business  Office Supplies
#
#   Product Sub-Category Product Container  \
# 0               Labels         Small Box
# 1   Office Furnishings         Small Box
# 2  Pens & Art Supplies          Wrap Bag
# 3  Pens & Art Supplies          Wrap Bag
# 4         Rubber Bands          Wrap Bag
#
#                                         Product Name  Product Base Margin  \
# 0                                           Avery 49                 0.36
# 1  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...                 0.43
# 2                                         Newell 321                 0.56
# 3                                         Newell 351                 0.56
# 4           OIC Colored Binder Clips, Assorted Sizes                 0.36
#
#     Region State or Province        City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois     Addison        60101 2012-05-28 2012-05-30
# 1  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-14
# 2  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 3  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
# 4  Central         Minnesota  Prior Lake        55372 2010-05-12 2010-05-13
#
#      Profit  Quantity ordered new    Sales  Order ID  Date_diff Manager
# 0    1.3200                     2     5.90     88525          2   Chris
# 1  803.4705                    16  1164.45     86838          2   Chris
# 2  -24.0300                     7    22.23     86838          1   Chris
# 3  -37.0300                     4    13.99     86838          1   Chris
# 4   -0.7100                     4    14.26     86838          1   Chris

# %%
# Now mergin these 2 dataframes

df = pd.merge(df1, df2)

df
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
#            Customer Name    Ship Mode Customer Segment Product Category  \
# 0   Tony Wilkins Winters  Regular Air   Small Business  Office Supplies
# 1            Linda Weiss  Regular Air      Home Office  Office Supplies
# 2            Linda Weiss  Express Air      Home Office  Office Supplies
# 3            Linda Weiss  Regular Air      Home Office  Office Supplies
# 4          Eleanor Swain  Regular Air   Small Business  Office Supplies
# ..                   ...          ...              ...              ...
# 93         Gordon Brandt  Regular Air        Corporate  Office Supplies
# 94         Gordon Brandt  Regular Air        Corporate  Office Supplies
# 95         Gordon Brandt  Express Air        Corporate  Office Supplies
# 96         Andrew Levine  Regular Air         Consumer       Technology
# 97          Peter Brooks  Regular Air   Small Business        Furniture
#
#       Product Sub-Category Product Container  \
# 0      Pens & Art Supplies          Wrap Bag
# 1                   Labels         Small Box
# 2                    Paper          Wrap Bag
# 3      Pens & Art Supplies          Wrap Bag
# 4      Pens & Art Supplies        Small Pack
# ..                     ...               ...
# 93                   Paper          Wrap Bag
# 94  Storage & Organization         Small Box
# 95                   Paper         Small Box
# 96    Computer Peripherals        Small Pack
# 97      Chairs & Chairmats        Medium Box
#
#                                          Product Name  Product Base Margin  \
# 0               Dixon My First Ticonderoga Pencil, #2                 0.56
# 1                                           Avery 493                 0.36
# 2                               EcoTones® Memo Sheets                 0.37
# 3                                           Newell 35                 0.56
# 4                   Staples SlimLine Pencil Sharpener                 0.60
# ..                                                ...                  ...
# 93  Snap-A-Way® Black Print Carbonless Ruled Speed...                 0.38
# 94  Recycled Steel Personal File for Standard File...                 0.59
# 95                                         Xerox 1980                 0.40
# 96                                   TDK 4.7GB DVD+RW                 0.49
# 97                        SAFCO Folding Chair Trolley                  NaN
#
#    Region State or Province           City  Postal Code Order Date  Ship Date  \
# 0    East          New York  New York City        10012 2011-04-20 2011-04-24
# 1    West        Washington        Seattle        98103 2010-04-04 2010-04-06
# 2    West        Washington        Seattle        98103 2010-04-04 2010-04-06
# 3    West        Washington        Seattle        98103 2013-08-16 2013-08-18
# 4   South    North Carolina      Charlotte        28204 2013-08-12 2013-08-12
# ..    ...               ...            ...          ...        ...        ...
# 93   West        California    Los Angeles        90061 2013-01-04 2013-01-06
# 94   West        California    Los Angeles        90061 2013-01-04 2013-01-05
# 95   West        California    Los Angeles        90061 2013-06-25 2013-06-27
# 96   East      Pennsylvania   Philadelphia        19112 2012-09-30 2012-10-02
# 97   East          New York  New York City        10112 2012-09-11 2012-09-13
#
#        Profit  Quantity ordered new     Sales  Order ID  Date_diff    Status  \
# 0     -6.8200                     9     54.79      9895          4  Returned
# 1    112.0600                    47    228.46     13959          2  Returned
# 2     16.7900                    19     77.61     13959          2  Returned
# 3    -89.0600                    52    190.52     36038          2  Returned
# 4    -81.9413                    76    912.06     39490          0  Returned
# ..        ...                   ...       ...       ...        ...       ...
# 93   -33.9680                     3    113.14      7107          2  Returned
# 94   163.1200                    35   1886.52      7107          1  Returned
# 95   -22.5600                    12     73.71     42823          2  Returned
# 96   165.2000                    96   1337.67     13638          2  Returned
# 97  1844.9600                    92  12002.16     47109          2  Returned
#
#     Manager
# 0      Erin
# 1   William
# 2   William
# 3   William
# 4       Sam
# ..      ...
# 93  William
# 94  William
# 95  William
# 96     Erin
# 97     Erin
#
# [98 rows x 27 columns]

# %%
filt = df['Date_diff'] > 15

len(df.loc[filt])
# Out:
# 0

# %% [markdown]
# **So there is no returned order after a duration of 15 days.**

# %%
# watching the df with only the required columns

df[['Order ID', 'Status', 'Date_diff', 'Manager']]
# Out:
#     Order ID    Status  Date_diff  Manager
# 0       9895  Returned          4     Erin
# 1      13959  Returned          2  William
# 2      13959  Returned          2  William
# 3      36038  Returned          2  William
# 4      39490  Returned          0      Sam
# ..       ...       ...        ...      ...
# 93      7107  Returned          2  William
# 94      7107  Returned          1  William
# 95     42823  Returned          2  William
# 96     13638  Returned          2     Erin
# 97     47109  Returned          2     Erin
#
# [98 rows x 4 columns]

# %% [markdown]
# #### 11. Gorup by region and find out which region is more profitable.

# %%
df_profit = df_order.groupby('Region')['Profit'].sum().sort_values(ascending = False).reset_index()

df_profit.rename(columns={'Profit' : 'Total_profit'}, inplace=True)

df_profit
# Out:
#     Region   Total_profit
# 0  Central  519825.567067
# 1     East  377566.186045
# 2     West  310849.453897
# 3    South  104201.192420

# %%
# So most profitable region is:

filt = (df_profit.Total_profit == df_profit.Total_profit.max())

df_profit.loc[filt]
# Out:
#     Region   Total_profit
# 0  Central  519825.567067

# %% [markdown]
# #### 12. Try to find out overall in which country we are giving more discount.

# %%
# There is no Country column instead we have State or Province

df_dsc = df_order.groupby('State or Province')['Discount'].sum().sort_values(ascending = False).reset_index()

df_dsc.rename(columns={'Discount' : 'Total_discount'}, inplace=True)

df_dsc
# Out:
#        State or Province  Total_discount
# 0             California           52.28
# 1                  Texas           31.36
# 2               Illinois           29.71
# 3               New York           28.86
# 4                Florida           26.38
# 5                   Ohio           19.71
# 6             Washington           15.48
# 7               Michigan           15.29
# 8           Pennsylvania           13.32
# 9              Minnesota           12.52
# 10               Indiana           12.22
# 11        North Carolina           12.02
# 12         Massachusetts           11.22
# 13              Virginia            9.80
# 14               Georgia            9.79
# 15              Maryland            8.85
# 16            New Jersey            8.73
# 17             Tennessee            8.55
# 18                Oregon            8.42
# 19              Missouri            8.09
# 20             Wisconsin            8.06
# 21              Colorado            8.05
# 22                  Utah            7.67
# 23                  Iowa            7.15
# 24                Kansas            6.89
# 25               Arizona            6.86
# 26                 Maine            6.66
# 27               Alabama            5.87
# 28              Arkansas            5.80
# 29                 Idaho            5.57
# 30        South Carolina            5.34
# 31              Oklahoma            5.17
# 32             Louisiana            4.86
# 33           Connecticut            4.28
# 34              Kentucky            4.23
# 35            New Mexico            4.08
# 36           Mississippi            3.89
# 37              Nebraska            3.59
# 38               Vermont            3.19
# 39  District of Columbia            3.10
# 40         New Hampshire            2.62
# 41               Montana            2.39
# 42         West Virginia            2.16
# 43                Nevada            1.80
# 44          North Dakota            1.71
# 45          South Dakota            1.30
# 46               Wyoming            1.15
# 47          Rhode Island            1.09
# 48              Delaware            0.66

# %%
# So highest discounted region is:

filt = (df_dsc.Total_discount == df_dsc.Total_discount.max())

df_dsc.loc[filt]
# Out:
#   State or Province  Total_discount
# 0        California           52.28

# %% [markdown]
# #### 13. Give me a list of unique postal codes.

# %%
unq_post = df_order['Postal Code'].unique()

print(list(unq_post))
# Out:
# [60101, 98221, 91776, 95123, 2724, 3110, 8101, 8109, 7203, 2907, 55372, 11787, 13210, 59405, 59601, 59801, 68005, 10012, 92653, 92677, 92530, 92630, 90712, 93534, 90260, 97405, 97526, 97030, 97123, 97303, 62002, 98373, 98052, 75019, 23834, 62701, 60107, 60477, 14150, 12180, 77642, 75080, 77471, 78664, 75088, 24153, 94043, 92563, 94559, 10177, 2917, 5401, 4070, 2331, 8830, 8701, 7470, 7481, 5201, 97035, 44708, 45231, 44105, 95687, 5451, 94591, 70056, 22102, 60601, 66209, 66215, 66502, 66062, 6510, 4401, 4005, 2129, 2038, 1852, 1752, 2067, 3820, 8618, 7644, 7110, 8861, 7095, 2895, 97128, 97504, 98103, 84118, 84041, 93277, 76903, 78207, 60004, 94952, 1510, 1106, 1880, 6401, 6360, 2664, 15122, 76148, 5439, 5403, 37664, 37918, 37086, 37087, 80525, 80817, 60452, 76131, 98059, 99352, 37804, 70802, 4092, 7024, 76240, 98158, 78415, 94122, 4011, 4240, 2474, 2540, 1580, 3038, 60505, 84043, 84321, 66212, 48138, 85335, 74006, 75217, 77536, 90660, 13501, 11580, 63114, 84044, 84047, 84107, 60453, 2021, 2766, 7101, 28227, 60302, 60462, 50208, 80027, 66203, 81503, 80634, 37922, 38109, 55423, 55901, 55113, 80126, 80232, 17331, 33772, 87505, 12208, 44106, 43229, 78589, 86001, 85234, 85301, 30297, 28204, 6824, 6111, 6226, 7109, 66614, 67212, 80538, 80233, 80134, 6830, 6770, 6855, 4073, 1069, 2725, 21234, 21128, 21208, 20854, 98115, 91945, 94404, 60130, 1007, 7111, 8052, 21133, 60510, 3045, 7410, 97045, 97206, 44221, 6478, 33181, 4101, 3246, 3101, 7010, 2878, 33132, 13601, 85338, 86401, 19406, 93727, 4072, 7628, 7071, 2816, 2910, 2886, 94601, 2149, 1840, 48234, 37814, 62223, 61008, 61701, 60440, 19026, 68025, 68801, 68847, 68502, 48509, 63105, 13021, 13905, 28001, 45406, 43015, 95240, 90805, 4901, 8360, 78666, 7026, 93405, 94403, 2358, 7201, 7032, 7666, 68104, 89701, 94583, 92704, 6010, 6108, 4330, 1462, 2370, 7047, 7480, 61801, 68701, 56301, 94024, 93635, 95032, 90266, 1923, 2457, 3054, 8332, 90069, 92683, 90604, 2019, 1915, 2341, 7506, 8601, 30318, 1845, 39180, 11704, 11795, 60543, 95020, 4106, 2062, 7042, 10154, 24281, 37130, 84404, 84057, 55416, 46041, 42104, 41011, 95336, 4038, 2148, 8753, 76067, 11226, 97756, 85204, 85737, 84062, 64064, 63043, 22025, 60061, 93101, 95051, 26501, 88201, 78155, 75090, 90008, 68046, 84604, 60067, 60068, 60087, 60185, 75081, 60187, 60090, 39701, 89015, 61554, 61604, 91767, 6415, 4210, 2032, 1801, 3301, 8021, 7031, 7054, 60091, 60517, 46016, 47401, 46032, 47201, 21136, 81001, 90045, 14224, 10605, 10701, 97301, 97477, 97224, 81007, 48195, 5701, 43952, 20852, 20602, 55106, 55378, 95062, 93454, 98119, 60544, 62301, 55379, 60089, 89115, 91730, 2116, 1540, 77373, 37211, 75203, 52501, 64133, 63301, 64506, 98387, 99207, 98408, 77478, 63116, 63376, 80229, 80030, 46307, 46312, 98105, 90041, 90405, 95404, 95070, 6040, 6460, 6850, 6702, 1520, 2152, 7067, 2840, 48841, 89031, 89041, 41042, 6614, 1803, 1420, 1089, 2190, 3053, 3079, 7003, 7016, 7039, 8232, 7901, 85345, 85023, 60423, 40324, 86301, 86314, 97062, 61201, 98661, 14215, 61107, 97068, 18103, 16602, 72143, 92054, 6033, 6484, 6437, 92691, 95351, 6512, 7001, 73064, 27502, 84067, 29915, 84106, 32168, 37830, 42420, 85254, 8046, 99362, 37167, 37174, 79605, 75002, 79109, 71854, 80033, 21222, 6511, 8002, 91745, 93117, 6114, 2210, 1450, 1060, 3839, 92544, 92345, 6405, 6810, 6492, 75503, 77590, 46514, 55126, 89502, 66202, 11575, 85635, 93422, 20746, 76017, 78745, 77520, 77705, 76021, 89431, 20024, 83616, 76201, 33430, 10039, 1887, 7652, 42240, 26003, 78521, 77803, 76028, 96003, 92374, 1463, 7008, 8857, 7050, 7501, 90278, 6776, 2127, 1605, 7002, 2914, 90049, 75482, 75067, 19901, 19711, 94061, 60610, 6105, 2108, 3842, 92503, 95677, 2339, 1841, 7079, 91761, 1718, 1701, 1040, 2151, 7650, 93030, 3431, 7601, 7450, 11720, 60459, 7712, 72022, 28806, 27217, 27511, 66762, 55125, 15221, 11722, 14225, 11725, 27514, 28205, 28027, 27707, 43017, 15102, 95695, 95991, 92399, 90004, 6473, 2109, 7030, 85351, 85374, 3060, 2864, 11727, 10573, 60409, 62901, 18018, 60441, 60174, 60193, 60076, 11729, 1 ...

# %% [markdown]
# #### 14. Which customer segement is more profitalble find it out.

# %%
df_cust = df_order.groupby('Customer Segment')['Profit'].sum().sort_values(ascending = False).reset_index()

df_cust.rename(columns={'Profit' : 'Total_profit'}, inplace=True)

df_cust
# Out:
#   Customer Segment   Total_profit
# 0        Corporate  505538.627783
# 1   Small Business  316474.592482
# 2      Home Office  283869.553814
# 3         Consumer  206559.625348

# %%
# So most profitable customer segment is:

filt = (df_cust.Total_profit == df_cust.Total_profit.max())

df_cust.loc[filt]
# Out:
#   Customer Segment   Total_profit
# 0        Corporate  505538.627783

# %% [markdown]
# #### 15. Try to find out the 10th most loss making product catagory.

# %%
df_loss = df_order.groupby('Product Sub-Category')['Profit'].sum().sort_values().reset_index()

df_loss.index = df_loss.index + 1

df_loss.rename(columns={'Profit' : 'Total_profit'}, inplace=True)

df_loss
# Out:
#               Product Sub-Category   Total_profit
# 1                           Tables  -72495.061875
# 2                        Bookcases   -7708.748564
# 3                     Rubber Bands   -2841.722459
# 4    Scissors, Rulers and Trimmers   -1936.849120
# 5              Pens & Art Supplies    1195.902840
# 6           Storage & Organization    8078.804727
# 7                           Labels   17775.320505
# 8                            Paper   35361.621738
# 9                        Envelopes   46133.223840
# 10            Computer Peripherals   87917.842513
# 11              Office Furnishings   92209.225867
# 12                      Appliances  121651.391380
# 13                 Copiers and Fax  129156.684030
# 14              Chairs & Chairmats  165348.882760
# 15                 Office Machines  168072.833340
# 16  Binders and Binder Accessories  226572.523042
# 17    Telephones and Communication  297950.524866

# %%
print(f"So the 10th most loss making product is {df_loss.loc[10, 'Product Sub-Category']}.")
# Out:
# So the 10th most loss making product is Computer Peripherals.

# %% [markdown]
# #### 16. Try to find out 10 top product with highest margins.

# %%
df_mgn = df1.groupby('Product Sub-Category')['Product Base Margin'].sum().sort_values(ascending=False).reset_index()

df_mgn.index = df_mgn.index + 1

df_mgn.rename(columns={'Product Base Margin' : 'Total_margin'}, inplace=True)

print("\nSo the top 10 products with highest margins are:")

df_mgn.head(10)
# Out:
# So the top 10 products with highest margins are:
#               Product Sub-Category  Total_margin
# 1                            Paper          6.10
# 2              Pens & Art Supplies          5.94
# 3             Computer Peripherals          5.55
# 4     Telephones and Communication          5.34
# 5   Binders and Binder Accessories          4.52
# 6               Office Furnishings          3.82
# 7           Storage & Organization          3.71
# 8                           Tables          3.21
# 9               Chairs & Chairmats          2.91
# 10                       Envelopes          1.89
